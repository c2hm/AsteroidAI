# %%
import gymnasium as gym
from gymnasium.spaces import Discrete, Tuple, Box
import numpy as np
import pygame
import random
import math

# %%
def human_render_loop(agent, env, transpose=False, print_step=False):
    obs, info = env.reset()

    clock = pygame.time.Clock()
    fps = env.metadata["render_fps"]

    pygame.display.init()
    size = env.render().shape[:2]
    if transpose:
        size = size[::-1]

    display = pygame.display.set_mode(size)

    term = trunc = quit = False
    step = 0
    total_reward = 0

    if print_step:
        print("initial state")
        print("\tobservation", obs)
        print("\tinfo", info)

    while not (term or trunc or quit):
        quit = pygame.key.get_pressed()[pygame.K_q]

        action = agent(obs)
        obs, reward, term, trunc, info = env.step(action)

        pygame.event.pump()

        step += 1
        total_reward += reward

        if print_step:
            print("step", step)
            print("\taction", action)
            print("\tobservation", obs)
            print("\treward", reward)
            print("\tterminated", term)
            print("\ttruncated", trunc)
            print("\tinfo", info)

        frame = env.render()
        if transpose:
            frame = frame.transpose((1, 0, 2))

        pygame.surfarray.blit_array(display, frame)
        pygame.display.flip()
        clock.tick(fps)

    if print_step:
        print("Total reward", total_reward)

    pygame.display.quit()

# %% [markdown]
# Game

# %%
HEIGHT = 600
WIDTH = 800

ASTEROID_NBR = 10
ASTEROID_SPEED = 5
ASTEROID_MIN_RADIUS = 50
ASTEROID_MAX_RADIUS = 150
SHIP_SPEED = 5
MISSILE_SPEED = 10

# Couleurs
WHITE = (150, 0, 0)
BLACK = (0, 0, 0)
YELLOW = (255, 255, 0)

# Chargement des images
ship_image = pygame.image.load("ship.png")
asteroid_base_image = pygame.image.load("asteroid.png")

# Rotation et redimensionnement de la fusée
ship_image = pygame.transform.rotate(ship_image, -90)  # Rotate 90 degrees to the right
ship_image = pygame.transform.scale(ship_image, (ship_image.get_width() // 2.5, ship_image.get_height() // 2.5))

# Classe pour la fusée
class Ship:
    def __init__(self):
        self.x = 50
        self.y = HEIGHT // 2
        self.speed = SHIP_SPEED
        self.vy = 0
        self.width = ship_image.get_width()
        self.height = ship_image.get_height()

    def update(self, dt):
        self.y += self.vy * dt * 100
        if self.y < 0:
            self.y = 0
        elif self.y > HEIGHT - self.height:
            self.y = HEIGHT - self.height

    def draw(self, screen):
        screen.blit(ship_image, (self.x, self.y))

    def get_collision_boxes(self):
        # Divides the ship into 3 smaller rectangles for better collision detection
        box_width = self.width // 3
        boxes = [
            pygame.Rect(self.x, self.y, box_width, self.height),  # Left box
            pygame.Rect(self.x + box_width, self.y + self.height / 2 / 2, box_width, self.height / 2),  # Middle box
            pygame.Rect(self.x + 2 * box_width, self.y + self.height / 2.65, box_width * 0.7, self.height / 4),  # Right box
            pygame.Rect(self.x + 2.7 * box_width, self.y + self.height / 2.265, box_width * 0.3, self.height / 8)  # Right box
        ]
        return boxes

class Missile:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.vx = MISSILE_SPEED

    def update(self, dt):
        self.x += self.vx * dt * 100

    def draw(self, screen):
        pygame.draw.rect(screen, YELLOW, (self.x, self.y - 2, 10, 4))

class Asteroid:
    def __init__(self):
        self.vx = ASTEROID_SPEED
        self.reset_position()
        self.spawn_delay = random.uniform(1, 3)
        self.spawn_time = pygame.time.get_ticks()  # Record the current time

    def reset_position(self):
        self.radius = random.randint(ASTEROID_MIN_RADIUS, ASTEROID_MAX_RADIUS)
        self.x = WIDTH + self.radius
        self.y = random.randint(0, HEIGHT)
        

    def update(self, dt):
        if pygame.time.get_ticks() - self.spawn_time > self.spawn_delay * 1000:
            self.x -= self.vx * dt * 100 
            if self.x < -self.radius * 2:
                self.reset_position()

    def draw(self, screen):
        image = pygame.transform.scale(asteroid_base_image, (self.radius * 2, self.radius * 2))
        screen.blit(image, (int(self.x - self.radius), int(self.y - self.radius)))

    def shrink(self):
        self.radius = int(self.radius * 0.75)
        if self.radius < 20:
            self.reset_position()

    def get_info(self):
        return self.x, self.y, self.radius

def check_ship_collision(ship, asteroids):
    collision_boxes = ship.get_collision_boxes()
    for asteroid in asteroids:
        for box in collision_boxes:
            if Collision_cicle_rect((asteroid.x, asteroid.y), asteroid.radius, (box.centerx, box.centery), box.width, box.height):
                return True
    return False

def Collision_cicle_rect(circle_center, circle_radius, rect_center, rect_width, rect_height):
    c_x, c_y = circle_center
    r_x, r_y = rect_center
    r_width, r_height = rect_width, rect_height

    # Calculate rectangle bounds
    r_min_x = r_x - r_width / 2
    r_max_x = r_x + r_width / 2
    r_min_y = r_y - r_height / 2
    r_max_y = r_y + r_height / 2

    # Find the closest point on the rectangle to the circle's center
    closest_x = max(r_min_x, min(c_x, r_max_x))
    closest_y = max(r_min_y, min(c_y, r_max_y))

    # Calculate distance from the circle's center to the closest point
    distance_squared = (c_x - closest_x) ** 2 + (c_y - closest_y) ** 2

    # Check for collision
    return distance_squared <= circle_radius ** 2

def check_missile_collision(missiles, asteroids):
    for missile in missiles[:]:
        for asteroid in asteroids:
            distance = math.hypot(missile.x - asteroid.x, missile.y - asteroid.y)
            if distance < asteroid.radius:
                asteroid.shrink()
                missiles.remove(missile)
                break

# %% [markdown]
# Environnement

# %%
class AsteroidEnv(gym.Env):
    metadata = {"render_modes": ["rgb_array"], "render_fps": 144}

    def __init__(self, worldSize=(WIDTH, HEIGHT), asteroidNbr = ASTEROID_NBR,  render_mode=None):
        super().__init__()

        self.worldSize = worldSize
        self.width = worldSize[0]
        self.height = worldSize[1]
        self.asteroidNbr = asteroidNbr
        self.dt = 1 / self.metadata["render_fps"]

        self.t = 0
        self.x = np.zeros(1 + 3*self.asteroidNbr)  # y + (x,y,r)*asteroidNbr   (xShip vyShip et vxAsteroid = constantes)
        self.u = np.zeros(3)  # up, down, shoot

        self.ship = Ship()
        self.asteroids = [Asteroid() for _ in range(asteroidNbr)]
        self.missiles = []

        self.observation_space = Box(
            low= np.zeros(1 + 3*self.asteroidNbr),
            high=np.array([self.height - self.ship.height] + [self.width + ASTEROID_MAX_RADIUS*2, self.height, ASTEROID_MAX_RADIUS] * self.asteroidNbr),
            shape=(1 + 3*self.asteroidNbr,),
            dtype=np.float32
        )
        self.action_space = Tuple((Discrete(2), Discrete(2), Discrete(2))) # up, down, shoot

        self.render_mode = render_mode

    def _dynamic_step(self, action):
        self.t += self.dt
        self.u = action

        # Move ship
        if self.u[0]:
            self.ship.vy = -self.ship.speed
        elif self.u[1]:
            self.ship.vy = self.ship.speed
        else:
            self.ship.vy = 0

        self.ship.update(self.dt)
        self.x[0] = self.ship.y

        # Move asteroids
        for asteroid in self.asteroids:
            asteroid.update(self.dt)
        self.x[1:] = [coord for a in self.asteroids for coord in a.get_info()]

        
        # Move missles
        if (self.u[2]):
            self.missiles.append(Missile(self.ship.x + self.ship.width, self.ship.y + self.ship.height // 2))

        for missile in self.missiles:
            missile.update(self.dt)
            if missile.x > WIDTH:
                self.missiles.remove(missile)

        # Check for collisions between asteroids and missles 
        check_missile_collision(self.missiles, self.asteroids)
         

    def _g(self):
        # u = self.u
        # delta_x = next_obs = self._get_observation()

        # # à compléter - la fonction de coût
        # Q = np.array([1.0, 1.0, 0.01, 0.01])
        # R = np.array([0.01, 0.01])

        # cout = (Q * delta_x**2).sum() + (R * u**2).sum() * self.dt

        # cout += 1000 * (not self.observation_space.contains(next_obs))

        # Reward survival
        return 1

    def _get_observation(self):
        return self.x

    def _should_truncate(self):
        return False #not self.observation_space.contains(self._get_observation())

    def _should_terminate(self):
        return check_ship_collision(self.ship, self.asteroids)
    
    def _get_info(self):
        return {
            "t": self.t
        }

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        self.t = 0

        observation = self.observation_space.sample()

        self.ship = Ship()
        self.asteroids = [Asteroid() for _ in range(self.asteroidNbr)]
        self.missiles = []

        self.x[0] = self.ship.y
        self.x[1:] = [coord for a in self.asteroids for coord in a.get_info()]

        observation = self._get_observation()

        self.u = np.zeros(3)

        info = self._get_info()

        return observation, info

    def step(self, action):
        # à compléter - les étape d'un step
        self._dynamic_step(action)
        observation = self._get_observation()
        reward = self._g()
        terminate = self._should_terminate()
        truncate = self._should_truncate()
        info = self._get_info()

        return observation, reward, terminate, truncate, info

    def render(self):
        if self.render_mode == "rgb_array":

            size = pygame.Vector2(self.worldSize)
            surface = pygame.Surface(size, flags=pygame.SRCALPHA)

            # Drawing the ship
            self.ship.draw(surface)

            # Drawing the asteroids
            for asteroid in self.asteroids:
                asteroid.draw(surface)

            # Drawing the missiles
            for missile in self.missiles:
                missile.draw(surface)

            return pygame.surfarray.pixels3d(surface)

# %%
gym.register(id="AsteroidEnv-v0", entry_point="__main__:AsteroidEnv")

env = gym.make("AsteroidEnv-v0", render_mode="rgb_array", max_episode_steps=1000)

# %%
def human_agent(_obs):
    keys = pygame.key.get_pressed()
    pygame.event.pump()

    if keys[pygame.K_UP] :
        up =1
    else:
        up = 0

    if keys[pygame.K_DOWN] :
        down =1
    else:
        down = 0

    if keys[pygame.K_SPACE] :
        space =1
    else:
        space = 0

    action = np.array([up,down,space])

    return action

# %%
human_render_loop(human_agent, env, print_step=True)
# Out:
# initial state
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	info {'t': 0}
# step 1
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.006944444444444444}
# step 2
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.013888888888888888}
# step 3
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.020833333333333332}
# step 4
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.027777777777777776}
# step 5
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.034722222222222224}
# step 6
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.04166666666666667}
# step 7
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.04861111111111112}
# step 8
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.055555555555555566}
# step 9
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.06250000000000001}
# step 10
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.06944444444444446}
# step 11
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.07638888888888891}
# step 12
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.08333333333333336}
# step 13
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.0902777777777778}
# step 14
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.09722222222222225}
# step 15
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.1041666666666667}
# step 16
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.11111111111111115}
# step 17
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.1180555555555556}
# step 18
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.12500000000000003}
# step 19
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.13194444444444448}
# step 20
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.13888888888888892}
# step 21
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.14583333333333337}
# step 22
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.15277777777777782}
# step 23
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.15972222222222227}
# step 24
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.1666666666666667}
# step 25
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.17361111111111116}
# step 26
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.1805555555555556}
# step 27
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.18750000000000006}
# step 28
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.1944444444444445}
# step 29
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.20138888888888895}
# step 30
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.2083333333333334}
# step 31
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.21527777777777785}
# step 32
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.2222222222222223}
# step 33
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.22916666666666674}
# step 34
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.2361111111111112}
# step 35
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.24305555555555564}
# step 36
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.25000000000000006}
# step 37
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.2569444444444445}
# step 38
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.2638888888888889}
# step 39
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.2708333333333333}
# step 40
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.27777777777777773}
# step 41
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.28472222222222215}
# step 42
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.2916666666666666}
# step 43
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.298611111111111}
# step 44
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.3055555555555554}
# step 45
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.31249999999999983}
# step 46
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.31944444444444425}
# step 47
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.3263888888888887}
# step 48
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.3333333333333331}
# step 49
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.3402777777777775}
# step 50
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.34722222222222193}
# step 51
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.35416666666666635}
# step 52
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.36111111111111077}
# step 53
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.3680555555555552}
# step 54
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.3749999999999996}
# step 55
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.38194444444444403}
# step 56
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.38888888888888845}
# step 57
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.39583333333333287}
# step 58
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.4027777777777773}
# step 59
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.4097222222222217}
# step 60
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.41666666666666613}
# step 61
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.42361111111111055}
# step 62
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.43055555555555497}
# step 63
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.4374999999999994}
# step 64
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.4444444444444438}
# step 65
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.45138888888888823}
# step 66
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.45833333333333265}
# step 67
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.46527777777777707}
# step 68
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.4722222222222215}
# step 69
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.4791666666666659}
# step 70
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.48611111111111033}
# step 71
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.49305555555555475}
# step 72
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.49999999999999917}
# step 73
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5069444444444436}
# step 74
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5138888888888881}
# step 75
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5208333333333325}
# step 76
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5277777777777769}
# step 77
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5347222222222213}
# step 78
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5416666666666657}
# step 79
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5486111111111102}
# step 80
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5555555555555546}
# step 81
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.562499999999999}
# step 82
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5694444444444434}
# step 83
# 	action [0 0 0]
# 	observation [300. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5763888888888878}
# step 84
# 	action [1 0 0]
# 	observation [296.52777778 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5833333333333323}
# step 85
# 	action [1 0 0]
# 	observation [293.05555556 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5902777777777767}
# step 86
# 	action [1 0 0]
# 	observation [289.58333333 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5972222222222211}
# step 87
# 	action [1 0 0]
# 	observation [286.11111111 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6041666666666655}
# step 88
# 	action [1 0 0]
# 	observation [282.63888889 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6111111111111099}
# step 89
# 	action [1 0 0]
# 	observation [279.16666667 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6180555555555544}
# step 90
# 	action [1 0 0]
# 	observation [275.69444444 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6249999999999988}
# step 91
# 	action [1 0 0]
# 	observation [272.22222222 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6319444444444432}
# step 92
# 	action [1 0 0]
# 	observation [268.75 864.   399.    64.   911.   171.   111.   914.   305.   114.
#  925.   122.   125.   924.   408.   124.   886.   533.    86.   947.
#  329.   147.   863.   252.    63.   857.   145.    57.   878.   441.
#   78.  ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6388888888888876}
# step 93
# 	action [1 0 0]
# 	observation [265.27777778 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.645833333333332}
# step 94
# 	action [1 0 0]
# 	observation [261.80555556 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6527777777777765}
# step 95
# 	action [1 0 0]
# 	observation [258.33333333 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6597222222222209}
# step 96
# 	action [1 0 0]
# 	observation [254.86111111 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6666666666666653}
# step 97
# 	action [1 0 0]
# 	observation [251.38888889 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6736111111111097}
# step 98
# 	action [1 0 0]
# 	observation [247.91666667 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6805555555555541}
# step 99
# 	action [1 0 0]
# 	observation [244.44444444 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6874999999999986}
# step 100
# 	action [1 0 0]
# 	observation [240.97222222 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.694444444444443}
# step 101
# 	action [1 0 0]
# 	observation [237.5 864.  399.   64.  911.  171.  111.  914.  305.  114.  925.  122.
#  125.  924.  408.  124.  886.  533.   86.  947.  329.  147.  863.  252.
#   63.  857.  145.   57.  878.  441.   78. ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7013888888888874}
# step 102
# 	action [1 0 0]
# 	observation [234.02777778 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7083333333333318}
# step 103
# 	action [1 0 0]
# 	observation [230.55555556 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7152777777777762}
# step 104
# 	action [1 0 0]
# 	observation [227.08333333 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7222222222222207}
# step 105
# 	action [1 0 1]
# 	observation [223.61111111 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7291666666666651}
# step 106
# 	action [1 0 1]
# 	observation [220.13888889 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7361111111111095}
# step 107
# 	action [1 0 1]
# 	observation [216.66666667 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7430555555555539}
# step 108
# 	action [1 0 1]
# 	observation [213.19444444 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7499999999999983}
# step 109
# 	action [1 0 1]
# 	observation [209.72222222 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7569444444444428}
# step 110
# 	action [1 0 1]
# 	observation [206.25 864.   399.    64.   911.   171.   111.   914.   305.   114.
#  925.   122.   125.   924.   408.   124.   886.   533.    86.   947.
#  329.   147.   863.   252.    63.   857.   145.    57.   878.   441.
#   78.  ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7638888888888872}
# step 111
# 	action [1 0 1]
# 	observation [202.77777778 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7708333333333316}
# step 112
# 	action [1 0 1]
# 	observation [199.30555556 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.777777777777776}
# step 113
# 	action [1 0 1]
# 	observation [195.83333333 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7847222222222204}
# step 114
# 	action [1 0 1]
# 	observation [192.36111111 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7916666666666649}
# step 115
# 	action [1 0 1]
# 	observation [188.88888889 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7986111111111093}
# step 116
# 	action [1 0 1]
# 	observation [185.41666667 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8055555555555537}
# step 117
# 	action [1 0 1]
# 	observation [181.94444444 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8124999999999981}
# step 118
# 	action [1 0 1]
# 	observation [178.47222222 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8194444444444425}
# step 119
# 	action [1 0 1]
# 	observation [175. 864. 399.  64. 911. 171. 111. 914. 305. 114. 925. 122. 125. 924.
#  408. 124. 886. 533.  86. 947. 329. 147. 863. 252.  63. 857. 145.  57.
#  878. 441.  78.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.826388888888887}
# step 120
# 	action [1 0 1]
# 	observation [171.52777778 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8333333333333314}
# step 121
# 	action [1 0 1]
# 	observation [168.05555556 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8402777777777758}
# step 122
# 	action [1 0 1]
# 	observation [164.58333333 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8472222222222202}
# step 123
# 	action [1 0 0]
# 	observation [161.11111111 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8541666666666646}
# step 124
# 	action [1 0 0]
# 	observation [157.63888889 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.861111111111109}
# step 125
# 	action [1 0 0]
# 	observation [154.16666667 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8680555555555535}
# step 126
# 	action [1 0 0]
# 	observation [150.69444444 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8749999999999979}
# step 127
# 	action [1 0 0]
# 	observation [147.22222222 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8819444444444423}
# step 128
# 	action [1 0 0]
# 	observation [143.75 864.   399.    64.   911.   171.   111.   914.   305.   114.
#  925.   122.   125.   924.   408.   124.   886.   533.    86.   947.
#  329.   147.   863.   252.    63.   857.   145.    57.   878.   441.
#   78.  ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8888888888888867}
# step 129
# 	action [1 0 0]
# 	observation [140.27777778 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8958333333333311}
# step 130
# 	action [1 0 0]
# 	observation [136.80555556 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.9027777777777756}
# step 131
# 	action [1 0 0]
# 	observation [133.33333333 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.90972222222222}
# step 132
# 	action [1 0 0]
# 	observation [129.86111111 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.9166666666666644}
# step 133
# 	action [1 0 0]
# 	observation [126.38888889 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.9236111111111088}
# step 134
# 	action [1 0 0]
# 	observation [122.91666667 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.9305555555555532}
# step 135
# 	action [1 0 0]
# 	observation [119.44444444 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.9374999999999977}
# step 136
# 	action [1 0 0]
# 	observation [115.97222222 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
#  329.         147.         863.         252.          63.
#  857.         145.          57.         878.         441.
#   78.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.9444444444444421}
# step 137
# 	action [1 0 1]
# 	observation [112.5 864.  399.   64.  911.  171.  111.  914.  305.  114.  925.  122.
#  125.  924.  408.  124.  886.  533.   86.  947.  329.  147.  863.  252.
#   63.  857.  145.   57.  878.  441.   78. ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.9513888888888865}
# step 138
# 	action [1 0 1]
# 	observation [109.02777778 864.         399.          64.         911.
#  171.         111.         914.         305.         114.
#  925.         122.         125.         924.         408.
#  124.         886.         533.          86.         947.
# ...
#  528.63888889 462.          90.         827.77777778 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.72222222222235}
# step 969
# 	action [0 1 1]
# 	observation [232.63888889 517.83333333 433.          54.         729.66666667
#  266.          42.         806.83333333  17.         111.
#  846.97222222 343.         106.         342.22222222 551.
#   70.         828.75       195.          60.           1.36111111
#  581.          59.         745.58333333 338.          81.
#  525.16666667 462.          90.         824.30555556 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.729166666666795}
# step 970
# 	action [0 1 1]
# 	observation [236.11111111 514.36111111 433.          54.         726.19444444
#  266.          42.         803.36111111  17.         111.
#  843.5        343.         106.         338.75       551.
#   70.         825.27777778 195.          60.          -2.11111111
#  581.          59.         742.11111111 338.          81.
#  521.69444444 462.          90.         820.83333333 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.7361111111112395}
# step 971
# 	action [0 1 1]
# 	observation [239.58333333 510.88888889 433.          54.         722.72222222
#  266.          42.         799.88888889  17.          83.
#  840.02777778 343.         106.         335.27777778 551.
#   70.         821.80555556 195.          60.          -5.58333333
#  581.          59.         738.63888889 338.          81.
#  518.22222222 462.          90.         817.36111111 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.743055555555684}
# step 972
# 	action [0 1 1]
# 	observation [243.05555556 507.41666667 433.          54.         719.25
#  266.          42.         796.41666667  17.          83.
#  836.55555556 343.         106.         331.80555556 551.
#   70.         818.33333333 195.          60.          -9.05555556
#  581.          59.         735.16666667 338.          81.
#  514.75       462.          90.         813.88888889 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.750000000000129}
# step 973
# 	action [0 1 1]
# 	observation [246.52777778 503.94444444 433.          54.         715.77777778
#  266.          42.         792.94444444  17.          83.
#  833.08333333 343.         106.         328.33333333 551.
#   70.         814.86111111 195.          60.         -12.52777778
#  581.          59.         731.69444444 338.          81.
#  511.27777778 462.          90.         810.41666667 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.756944444444573}
# step 974
# 	action [0 1 1]
# 	observation [250.         500.47222222 433.          54.         712.30555556
#  266.          42.         789.47222222  17.          62.
#  829.61111111 343.         106.         324.86111111 551.
#   70.         811.38888889 195.          60.         -16.
#  581.          59.         728.22222222 338.          81.
#  507.80555556 462.          90.         806.94444444 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.763888888889018}
# step 975
# 	action [0 1 1]
# 	observation [253.47222222 497.         433.          54.         708.83333333
#  266.          42.         786.          17.          62.
#  826.13888889 343.         106.         321.38888889 551.
#   70.         807.91666667 195.          60.         -19.47222222
#  581.          59.         724.75       338.          81.
#  504.33333333 462.          90.         803.47222222 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.770833333333463}
# step 976
# 	action [0 1 1]
# 	observation [256.94444444 493.52777778 433.          54.         705.36111111
#  266.          42.         782.52777778  17.          62.
#  822.66666667 343.         106.         317.91666667 551.
#   70.         804.44444444 195.          60.         -22.94444444
#  581.          59.         721.27777778 338.          81.
#  500.86111111 462.          90.         800.         137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.777777777777907}
# step 977
# 	action [0 1 1]
# 	observation [260.41666667 490.05555556 433.          54.         701.88888889
#  266.          42.         779.05555556  17.          62.
#  819.19444444 343.         106.         314.44444444 551.
#   70.         800.97222222 195.          60.         -26.41666667
#  581.          59.         717.80555556 338.          81.
#  497.38888889 462.          90.         796.52777778 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.784722222222352}
# step 978
# 	action [0 1 1]
# 	observation [263.88888889 486.58333333 433.          54.         698.41666667
#  266.          42.         775.58333333  17.          46.
#  815.72222222 343.         106.         310.97222222 551.
#   70.         797.5        195.          60.         -29.88888889
#  581.          59.         714.33333333 338.          81.
#  493.91666667 462.          90.         793.05555556 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.791666666666797}
# step 979
# 	action [0 1 1]
# 	observation [267.36111111 483.11111111 433.          54.         694.94444444
#  266.          42.         772.11111111  17.          46.
#  812.25       343.         106.         307.5        551.
#   70.         794.02777778 195.          60.         -33.36111111
#  581.          59.         710.86111111 338.          81.
#  490.44444444 462.          90.         789.58333333 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.798611111111241}
# step 980
# 	action [0 1 1]
# 	observation [270.83333333 479.63888889 433.          54.         691.47222222
#  266.          42.         768.63888889  17.          46.
#  808.77777778 343.         106.         304.02777778 551.
#   70.         790.55555556 195.          60.         -36.83333333
#  581.          59.         707.38888889 338.          81.
#  486.97222222 462.          90.         786.11111111 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.805555555555686}
# step 981
# 	action [0 1 1]
# 	observation [274.30555556 476.16666667 433.          54.         688.
#  266.          42.         765.16666667  17.          34.
#  805.30555556 343.         106.         300.55555556 551.
#   70.         787.08333333 195.          60.         -40.30555556
#  581.          59.         703.91666667 338.          81.
#  483.5        462.          90.         782.63888889 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.812500000000131}
# step 982
# 	action [0 1 1]
# 	observation [277.77777778 472.69444444 433.          54.         684.52777778
#  266.          42.         761.69444444  17.          34.
#  801.83333333 343.         106.         297.08333333 551.
#   70.         783.61111111 195.          60.         -43.77777778
#  581.          59.         700.44444444 338.          81.
#  480.02777778 462.          90.         779.16666667 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.819444444444575}
# step 983
# 	action [0 1 1]
# 	observation [281.25       469.22222222 433.          54.         681.05555556
#  266.          42.         758.22222222  17.          34.
#  798.36111111 343.         106.         293.61111111 551.
#   70.         780.13888889 195.          60.         -47.25
#  581.          59.         696.97222222 338.          81.
#  476.55555556 462.          90.         775.69444444 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.82638888888902}
# step 984
# 	action [0 1 1]
# 	observation [284.72222222 465.75       433.          54.         677.58333333
#  266.          42.         754.75        17.          25.
#  794.88888889 343.         106.         290.13888889 551.
#   70.         776.66666667 195.          60.         -50.72222222
#  581.          59.         693.5        338.          81.
#  473.08333333 462.          90.         772.22222222 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.8333333333334645}
# step 985
# 	action [0 1 1]
# 	observation [288.19444444 462.27777778 433.          54.         674.11111111
#  266.          42.         751.27777778  17.          25.
#  791.41666667 343.         106.         286.66666667 551.
#   70.         773.19444444 195.          60.         -54.19444444
#  581.          59.         690.02777778 338.          81.
#  469.61111111 462.          90.         768.75       137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.840277777777909}
# step 986
# 	action [0 1 1]
# 	observation [291.66666667 458.80555556 433.          54.         670.63888889
#  266.          42.         893.52777778 282.          97.
#  787.94444444 343.         106.         283.19444444 551.
#   70.         769.72222222 195.          60.         -57.66666667
#  581.          59.         686.55555556 338.          81.
#  466.13888889 462.          90.         765.27777778 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.847222222222354}
# step 987
# 	action [0 1 1]
# 	observation [295.13888889 455.33333333 433.          54.         667.16666667
#  266.          42.         890.05555556 282.          97.
#  784.47222222 343.         106.         279.72222222 551.
#   70.         766.25       195.          60.         -61.13888889
#  581.          59.         683.08333333 338.          81.
#  462.66666667 462.          90.         761.80555556 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.854166666666798}
# step 988
# 	action [0 1 1]
# 	observation [298.61111111 451.86111111 433.          54.         663.69444444
#  266.          42.         886.58333333 282.          97.
#  781.         343.         106.         276.25       551.
#   70.         762.77777778 195.          60.         -64.61111111
#  581.          59.         679.61111111 338.          81.
#  459.19444444 462.          90.         758.33333333 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.861111111111243}
# step 989
# 	action [0 1 1]
# 	observation [302.08333333 448.38888889 433.          54.         660.22222222
#  266.          42.         883.11111111 282.          97.
#  777.52777778 343.         106.         272.77777778 551.
#   70.         759.30555556 195.          60.         -68.08333333
#  581.          59.         676.13888889 338.          81.
#  455.72222222 462.          90.         754.86111111 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.868055555555688}
# step 990
# 	action [0 1 1]
# 	observation [305.55555556 444.91666667 433.          54.         656.75
#  266.          42.         879.63888889 282.          97.
#  774.05555556 343.         106.         269.30555556 551.
#   70.         755.83333333 195.          60.         -71.55555556
#  581.          59.         672.66666667 338.          81.
#  452.25       462.          90.         751.38888889 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.875000000000132}
# step 991
# 	action [0 1 1]
# 	observation [309.02777778 441.44444444 433.          54.         653.27777778
#  266.          42.         876.16666667 282.          97.
#  770.58333333 343.         106.         265.83333333 551.
#   70.         752.36111111 195.          60.         -75.02777778
#  581.          59.         669.19444444 338.          81.
#  448.77777778 462.          90.         747.91666667 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.881944444444577}
# step 992
# 	action [0 1 1]
# 	observation [312.5        437.97222222 433.          54.         649.80555556
#  266.          42.         872.69444444 282.          97.
#  767.11111111 343.         106.         262.36111111 551.
#   70.         748.88888889 195.          60.         -78.5
#  581.          59.         665.72222222 338.          81.
#  445.30555556 462.          90.         744.44444444 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.888888888889022}
# step 993
# 	action [0 1 1]
# 	observation [315.97222222 434.5        433.          54.         646.33333333
#  266.          42.         869.22222222 282.          97.
#  763.63888889 343.         106.         258.88888889 551.
#   70.         745.41666667 195.          60.         -81.97222222
#  581.          59.         662.25       338.          81.
#  441.83333333 462.          90.         740.97222222 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.895833333333466}
# step 994
# 	action [1 1 1]
# 	observation [312.5        431.02777778 433.          54.         642.86111111
#  266.          42.         865.75       282.          97.
#  760.16666667 343.         106.         255.41666667 551.
#   70.         741.94444444 195.          60.         -85.44444444
#  581.          59.         658.77777778 338.          81.
#  438.36111111 462.          90.         737.5        137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.902777777777911}
# step 995
# 	action [1 1 1]
# 	observation [309.02777778 427.55555556 433.          54.         639.38888889
#  266.          42.         862.27777778 282.          97.
#  756.69444444 343.         106.         251.94444444 551.
#   70.         738.47222222 195.          60.         -88.91666667
#  581.          59.         655.30555556 338.          81.
#  434.88888889 462.          90.         734.02777778 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.9097222222223555}
# step 996
# 	action [1 1 1]
# 	observation [305.55555556 424.08333333 433.          54.         635.91666667
#  266.          42.         858.80555556 282.          97.
#  753.22222222 343.         106.         248.47222222 551.
#   70.         735.         195.          60.         -92.38888889
#  581.          59.         651.83333333 338.          81.
#  431.41666667 462.          90.         730.55555556 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.9166666666668}
# step 997
# 	action [1 1 1]
# 	observation [302.08333333 420.61111111 433.          54.         632.44444444
#  266.          42.         855.33333333 282.          97.
#  749.75       343.         106.         245.         551.
#   70.         731.52777778 195.          60.         -95.86111111
#  581.          59.         648.36111111 338.          81.
#  427.94444444 462.          90.         727.08333333 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.923611111111245}
# step 998
# 	action [1 1 1]
# 	observation [298.61111111 417.13888889 433.          54.         628.97222222
#  266.          42.         851.86111111 282.          97.
#  746.27777778 343.         106.         241.52777778 551.
#   70.         728.05555556 195.          60.         -99.33333333
#  581.          59.         644.88888889 338.          81.
#  424.47222222 462.          90.         723.61111111 137.
#   38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.9305555555556895}
# step 999
# 	action [1 0 1]
# 	observation [ 295.13888889  413.66666667  433.           54.          625.5
#   266.           42.          848.38888889  282.           97.
#   742.80555556  343.          106.          238.05555556  551.
#    70.          724.58333333  195.           60.         -102.80555556
#   581.           59.          641.41666667  338.           81.
#   421.          462.           90.          720.13888889  137.
#    38.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 6.937500000000134}
# step 1000
# 	action [1 0 1]
# 	observation [ 291.66666667  410.19444444  433.           54.          622.02777778
#   266.           42.          844.91666667  282.           97.
#   739.33333333  343.          106.          234.58333333  551.
#    70.          721.11111111  195.           60.         -106.27777778
#   581.           59.          637.94444444  338.           81.
#   417.52777778  462.           90.          716.66666667  137.
#    38.        ]
# 	reward 1
# 	terminated False
# 	truncated True
# 	info {'t': 6.944444444444579}
# Total reward 1000
