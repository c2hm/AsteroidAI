# %%
import gymnasium as gym
from gymnasium.spaces import Discrete, Tuple, Box, MultiBinary
from stable_baselines3 import PPO
import numpy as np
import pygame
import random
import math

# %%
def human_render_loop(agent, env, transpose=False, print_step=False):
    obs, info = env.reset()

    clock = pygame.time.Clock()
    fps = env.metadata["render_fps"]

    pygame.display.init()
    size = env.render().shape[:2]
    if transpose:
        size = size[::-1]

    display = pygame.display.set_mode(size)

    term = trunc = quit = False
    step = 0
    total_reward = 0

    if print_step:
        print("initial state")
        print("\tobservation", obs)
        print("\tinfo", info)

    while not (term or trunc or quit):
        quit = pygame.key.get_pressed()[pygame.K_q]

        action = agent(obs)
        obs, reward, term, trunc, info = env.step(action)

        pygame.event.pump()

        step += 1
        total_reward += reward

        if print_step:
            print("step", step)
            print("\taction", action)
            print("\tobservation", obs)
            print("\treward", reward)
            print("\tterminated", term)
            print("\ttruncated", trunc)
            print("\tinfo", info)

        frame = env.render()
        if transpose:
            frame = frame.transpose((1, 0, 2))

        pygame.surfarray.blit_array(display, frame)
        pygame.display.flip()
        clock.tick(fps)

    if print_step:
        print("Total reward", total_reward)

    pygame.display.quit()

# %% [markdown]
# Game

# %%
HEIGHT = 600
WIDTH = 800

ASTEROID_NBR = 3
ASTEROID_SPEED = 5
ASTEROID_MIN_RADIUS = 50
ASTEROID_MAX_RADIUS = 150
SHIP_SPEED = 5
MISSILE_SPEED = 10

DT_MILLIS = 50

# Couleurs
WHITE = (150, 0, 0)
BLACK = (0, 0, 0)
YELLOW = (255, 255, 0)

# Chargement des images
ship_image = pygame.image.load("ship.png")
asteroid_base_image = pygame.image.load("asteroid.png")

ship_image.set_colorkey((0, 0, 0)) # Set black as the transparent color
asteroid_base_image.set_colorkey((0, 0, 0)) # Set black as the transparent color

# Rotation et redimensionnement de la fusée
ship_image = pygame.transform.rotate(ship_image, -90)  # Rotate 90 degrees to the right
ship_image = pygame.transform.scale(ship_image, (ship_image.get_width() // 2.5, ship_image.get_height() // 2.5))

# Classe pour la fusée
class Ship:
    def __init__(self):
        self.x = 50
        self.y = HEIGHT // 2
        self.speed = SHIP_SPEED
        self.vy = 0
        self.width = ship_image.get_width()
        self.height = ship_image.get_height()

    def update(self, dt):
        self.y += self.vy * dt * DT_MILLIS 
        if self.y < 0:
            self.y = 0
        elif self.y > HEIGHT - self.height:
            self.y = HEIGHT - self.height

    def draw(self, screen):
        screen.blit(ship_image, (self.x, self.y))

    def get_collision_boxes(self):
        # Divides the ship into 3 smaller rectangles for better collision detection
        box_width = self.width // 3
        boxes = [
            pygame.Rect(self.x, self.y, box_width, self.height),  # Left box
            pygame.Rect(self.x + box_width, self.y + self.height / 2 / 2, box_width, self.height / 2),  # Middle box
            pygame.Rect(self.x + 2 * box_width, self.y + self.height / 2.65, box_width * 0.7, self.height / 4),  # Right box
            pygame.Rect(self.x + 2.7 * box_width, self.y + self.height / 2.265, box_width * 0.3, self.height / 8)  # Right box
        ]
        return boxes

class Missile:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.vx = MISSILE_SPEED

    def update(self, dt):
        self.x += self.vx * dt * DT_MILLIS 

    def draw(self, screen):
        pygame.draw.rect(screen, YELLOW, (self.x, self.y - 2, 10, 4))

class Asteroid:
    def __init__(self):
        self.vx = ASTEROID_SPEED
        self.reset_position()
        self.spawn_delay = random.uniform(1, 3)
        self.spawn_time = pygame.time.get_ticks()  # Record the current time

    def reset_position(self):
        self.radius = random.randint(ASTEROID_MIN_RADIUS, ASTEROID_MAX_RADIUS)
        self.x = WIDTH + self.radius
        self.y = random.randint(0, HEIGHT)
        

    def update(self, dt):
        if pygame.time.get_ticks() - self.spawn_time > self.spawn_delay * 1000:
            self.x -= self.vx * dt * DT_MILLIS 
            if self.x < -self.radius * 2:
                self.reset_position()

    def draw(self, screen):
        image = pygame.transform.scale(asteroid_base_image, (self.radius * 2, self.radius * 2))
        screen.blit(image, (int(self.x - self.radius), int(self.y - self.radius)))

    def shrink(self):
        self.radius = int(self.radius * 0.75)
        if self.radius < 20:
            self.reset_position()

    def get_info(self):
        return self.x, self.y, self.radius

def check_ship_collision(ship, asteroids):
    collision_boxes = ship.get_collision_boxes()
    for asteroid in asteroids:
        for box in collision_boxes:
            if Collision_cicle_rect((asteroid.x, asteroid.y), asteroid.radius, (box.centerx, box.centery), box.width, box.height):
                return True
    return False

def Collision_cicle_rect(circle_center, circle_radius, rect_center, rect_width, rect_height):
    c_x, c_y = circle_center
    r_x, r_y = rect_center
    r_width, r_height = rect_width, rect_height

    # Calculate rectangle bounds
    r_min_x = r_x - r_width / 2
    r_max_x = r_x + r_width / 2
    r_min_y = r_y - r_height / 2
    r_max_y = r_y + r_height / 2

    # Find the closest point on the rectangle to the circle's center
    closest_x = max(r_min_x, min(c_x, r_max_x))
    closest_y = max(r_min_y, min(c_y, r_max_y))

    # Calculate distance from the circle's center to the closest point
    distance_squared = (c_x - closest_x) ** 2 + (c_y - closest_y) ** 2

    # Check for collision
    return distance_squared <= circle_radius ** 2

def check_missile_collision(missiles, asteroids):
    for missile in missiles[:]:
        for asteroid in asteroids:
            distance = math.hypot(missile.x - asteroid.x, missile.y - asteroid.y)
            if distance < asteroid.radius:
                asteroid.shrink()
                missiles.remove(missile)
                break

# %% [markdown]
# Environnement

# %%
class AsteroidEnv(gym.Env):
    metadata = {"render_modes": ["rgb_array"], "render_fps": 30}

    def __init__(self, worldSize=(WIDTH, HEIGHT), asteroidNbr = ASTEROID_NBR,  render_mode=None):
        super().__init__()

        self.worldSize = worldSize
        self.width = worldSize[0]
        self.height = worldSize[1]
        self.asteroidNbr = asteroidNbr
        self.dt = 1 / self.metadata["render_fps"]

        self.t = 0
        self.x = np.zeros(1 + 3*self.asteroidNbr)  # y + (x,y,r)*asteroidNbr   (xShip vyShip et vxAsteroid = constantes)
        self.u = np.zeros(3)  # up, down, shoot

        self.ship = Ship()
        self.asteroids = [Asteroid() for _ in range(asteroidNbr)]
        self.missiles = []

        self.observation_space = Box(
            low= np.zeros(1 + 3*self.asteroidNbr),
            high=np.array([self.height - self.ship.height] + [self.width + ASTEROID_MAX_RADIUS*2, self.height, ASTEROID_MAX_RADIUS] * self.asteroidNbr),
            shape=(1 + 3*self.asteroidNbr,),
            dtype=np.float32
        )
        self.action_space = MultiBinary(3) # up, down, shoot

        self.render_mode = render_mode

    def _dynamic_step(self, action):
        self.t += self.dt
        self.u = action

        # Move ship
        if self.u[0]:
            self.ship.vy = -self.ship.speed
        elif self.u[1]:
            self.ship.vy = self.ship.speed
        else:
            self.ship.vy = 0

        self.ship.update(self.dt)
        self.x[0] = self.ship.y

        # Move asteroids
        for asteroid in self.asteroids:
            asteroid.update(self.dt)
        self.x[1:] = [coord for a in self.asteroids for coord in a.get_info()]

        
        # Move missles
        if (self.u[2]):
            self.missiles.append(Missile(self.ship.x + self.ship.width, self.ship.y + self.ship.height // 2))

        for missile in self.missiles:
            missile.update(self.dt)
            if missile.x > WIDTH:
                self.missiles.remove(missile)

        # Check for collisions between asteroids and missles 
        check_missile_collision(self.missiles, self.asteroids)
         

    def _g(self):
        # u = self.u
        # delta_x = next_obs = self._get_observation()

        # # à compléter - la fonction de coût
        # Q = np.array([1.0, 1.0, 0.01, 0.01])
        # R = np.array([0.01, 0.01])

        # cout = (Q * delta_x**2).sum() + (R * u**2).sum() * self.dt

        # cout += 1000 * (not self.observation_space.contains(next_obs))

        # Reward survival
        return self.t

    def _get_observation(self):
        return self.x

    def _should_truncate(self):
        return False #not self.observation_space.contains(self._get_observation())

    def _should_terminate(self):
        return check_ship_collision(self.ship, self.asteroids)
    
    def _get_info(self):
        return {
            "t": self.t
        }

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        self.t = 0

        observation = self.observation_space.sample()

        self.ship = Ship()
        self.asteroids = [Asteroid() for _ in range(self.asteroidNbr)]
        self.missiles = []

        self.x[0] = self.ship.y
        self.x[1:] = [coord for a in self.asteroids for coord in a.get_info()]

        observation = self._get_observation()

        self.u = np.zeros(3)

        info = self._get_info()

        return observation, info

    def step(self, action):
        # à compléter - les étape d'un step
        self._dynamic_step(action)
        observation = self._get_observation()
        reward = self._g()
        terminate = self._should_terminate()
        truncate = self._should_truncate()
        info = self._get_info()

        return observation, reward, terminate, truncate, info

    def render(self):
        if self.render_mode == "rgb_array":

            size = pygame.Vector2(self.worldSize)
            surface = pygame.Surface(size, flags=pygame.SRCALPHA)

            # Drawing the ship
            self.ship.draw(surface)

            # Drawing the asteroids
            for asteroid in self.asteroids:
                asteroid.draw(surface)

            # Drawing the missiles
            for missile in self.missiles:
                missile.draw(surface)

            return pygame.surfarray.pixels3d(surface)

# %%
gym.register(id="AsteroidEnv-v0", entry_point="__main__:AsteroidEnv")

env = gym.make("AsteroidEnv-v0", render_mode="rgb_array", max_episode_steps=10000)

# %%
def human_agent(_obs):
    keys = pygame.key.get_pressed()
    pygame.event.pump()

    action = np.array([keys[pygame.K_UP],keys[pygame.K_DOWN],keys[pygame.K_SPACE]])

    return action

human_render_loop(human_agent, env, print_step=True)
# Out:
# c:\Users\Charles Henri\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\utils\passive_env_checker.py:135: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# c:\Users\Charles Henri\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\utils\passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# c:\Users\Charles Henri\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\utils\passive_env_checker.py:135: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# c:\Users\Charles Henri\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\utils\passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# initial state
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	info {'t': 0}
# step 1
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.03333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.03333333333333333}
# step 2
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.06666666666666667
# 	terminated False
# 	truncated False
# 	info {'t': 0.06666666666666667}
# step 3
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.1
# 	terminated False
# 	truncated False
# 	info {'t': 0.1}
# step 4
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.13333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.13333333333333333}
# step 5
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.16666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 0.16666666666666666}
# step 6
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.19999999999999998
# 	terminated False
# 	truncated False
# 	info {'t': 0.19999999999999998}
# step 7
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.2333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.2333333333333333}
# step 8
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.26666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 0.26666666666666666}
# step 9
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.3
# 	terminated False
# 	truncated False
# 	info {'t': 0.3}
# step 10
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.3333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.3333333333333333}
# step 11
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.36666666666666664
# 	terminated False
# 	truncated False
# 	info {'t': 0.36666666666666664}
# step 12
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.39999999999999997
# 	terminated False
# 	truncated False
# 	info {'t': 0.39999999999999997}
# step 13
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.4333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.4333333333333333}
# step 14
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.4666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 0.4666666666666666}
# step 15
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.49999999999999994
# 	terminated False
# 	truncated False
# 	info {'t': 0.49999999999999994}
# step 16
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.5333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.5333333333333333}
# step 17
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.5666666666666667
# 	terminated False
# 	truncated False
# 	info {'t': 0.5666666666666667}
# step 18
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.6
# 	terminated False
# 	truncated False
# 	info {'t': 0.6}
# step 19
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.6333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.6333333333333333}
# step 20
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.6666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 0.6666666666666666}
# step 21
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.7
# 	terminated False
# 	truncated False
# 	info {'t': 0.7}
# step 22
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.7333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.7333333333333333}
# step 23
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.7666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 0.7666666666666666}
# step 24
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.7999999999999999
# 	terminated False
# 	truncated False
# 	info {'t': 0.7999999999999999}
# step 25
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.8333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.8333333333333333}
# step 26
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.8666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 0.8666666666666666}
# step 27
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.8999999999999999
# 	terminated False
# 	truncated False
# 	info {'t': 0.8999999999999999}
# step 28
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.9333333333333332
# 	terminated False
# 	truncated False
# 	info {'t': 0.9333333333333332}
# step 29
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.9666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 0.9666666666666666}
# step 30
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 0.9999999999999999
# 	terminated False
# 	truncated False
# 	info {'t': 0.9999999999999999}
# step 31
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.0333333333333332
# 	terminated False
# 	truncated False
# 	info {'t': 1.0333333333333332}
# step 32
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.0666666666666667
# 	terminated False
# 	truncated False
# 	info {'t': 1.0666666666666667}
# step 33
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.1
# 	terminated False
# 	truncated False
# 	info {'t': 1.1}
# step 34
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.1333333333333335
# 	terminated False
# 	truncated False
# 	info {'t': 1.1333333333333335}
# step 35
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.166666666666667
# 	terminated False
# 	truncated False
# 	info {'t': 1.166666666666667}
# step 36
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.2000000000000004
# 	terminated False
# 	truncated False
# 	info {'t': 1.2000000000000004}
# step 37
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.2333333333333338
# 	terminated False
# 	truncated False
# 	info {'t': 1.2333333333333338}
# step 38
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.2666666666666673
# 	terminated False
# 	truncated False
# 	info {'t': 1.2666666666666673}
# step 39
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.3000000000000007
# 	terminated False
# 	truncated False
# 	info {'t': 1.3000000000000007}
# step 40
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.3333333333333341
# 	terminated False
# 	truncated False
# 	info {'t': 1.3333333333333341}
# step 41
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.3666666666666676
# 	terminated False
# 	truncated False
# 	info {'t': 1.3666666666666676}
# step 42
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.400000000000001
# 	terminated False
# 	truncated False
# 	info {'t': 1.400000000000001}
# step 43
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.4333333333333345
# 	terminated False
# 	truncated False
# 	info {'t': 1.4333333333333345}
# step 44
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.466666666666668
# 	terminated False
# 	truncated False
# 	info {'t': 1.466666666666668}
# step 45
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.5000000000000013
# 	terminated False
# 	truncated False
# 	info {'t': 1.5000000000000013}
# step 46
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 948. 130. 148.]
# 	reward 1.5333333333333348
# 	terminated False
# 	truncated False
# 	info {'t': 1.5333333333333348}
# step 47
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         939.66666667 130.         148.        ]
# 	reward 1.5666666666666682
# 	terminated False
# 	truncated False
# 	info {'t': 1.5666666666666682}
# step 48
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         931.33333333 130.         148.        ]
# 	reward 1.6000000000000016
# 	terminated False
# 	truncated False
# 	info {'t': 1.6000000000000016}
# step 49
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 923. 130. 148.]
# 	reward 1.633333333333335
# 	terminated False
# 	truncated False
# 	info {'t': 1.633333333333335}
# step 50
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         914.66666667 130.         148.        ]
# 	reward 1.6666666666666685
# 	terminated False
# 	truncated False
# 	info {'t': 1.6666666666666685}
# step 51
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         906.33333333 130.         148.        ]
# 	reward 1.700000000000002
# 	terminated False
# 	truncated False
# 	info {'t': 1.700000000000002}
# step 52
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 898. 130. 148.]
# 	reward 1.7333333333333354
# 	terminated False
# 	truncated False
# 	info {'t': 1.7333333333333354}
# step 53
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         889.66666667 130.         148.        ]
# 	reward 1.7666666666666688
# 	terminated False
# 	truncated False
# 	info {'t': 1.7666666666666688}
# step 54
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         881.33333333 130.         148.        ]
# 	reward 1.8000000000000023
# 	terminated False
# 	truncated False
# 	info {'t': 1.8000000000000023}
# step 55
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 873. 130. 148.]
# 	reward 1.8333333333333357
# 	terminated False
# 	truncated False
# 	info {'t': 1.8333333333333357}
# step 56
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         864.66666667 130.         148.        ]
# 	reward 1.8666666666666691
# 	terminated False
# 	truncated False
# 	info {'t': 1.8666666666666691}
# step 57
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         856.33333333 130.         148.        ]
# 	reward 1.9000000000000026
# 	terminated False
# 	truncated False
# 	info {'t': 1.9000000000000026}
# step 58
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 848. 130. 148.]
# 	reward 1.933333333333336
# 	terminated False
# 	truncated False
# 	info {'t': 1.933333333333336}
# step 59
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         839.66666667 130.         148.        ]
# 	reward 1.9666666666666694
# 	terminated False
# 	truncated False
# 	info {'t': 1.9666666666666694}
# step 60
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         831.33333333 130.         148.        ]
# 	reward 2.0000000000000027
# 	terminated False
# 	truncated False
# 	info {'t': 2.0000000000000027}
# step 61
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 823. 130. 148.]
# 	reward 2.033333333333336
# 	terminated False
# 	truncated False
# 	info {'t': 2.033333333333336}
# step 62
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         814.66666667 130.         148.        ]
# 	reward 2.066666666666669
# 	terminated False
# 	truncated False
# 	info {'t': 2.066666666666669}
# step 63
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         806.33333333 130.         148.        ]
# 	reward 2.1000000000000023
# 	terminated False
# 	truncated False
# 	info {'t': 2.1000000000000023}
# step 64
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 798. 130. 148.]
# 	reward 2.1333333333333355
# 	terminated False
# 	truncated False
# 	info {'t': 2.1333333333333355}
# step 65
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         789.66666667 130.         148.        ]
# 	reward 2.1666666666666687
# 	terminated False
# 	truncated False
# 	info {'t': 2.1666666666666687}
# step 66
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         781.33333333 130.         148.        ]
# 	reward 2.200000000000002
# 	terminated False
# 	truncated False
# 	info {'t': 2.200000000000002}
# step 67
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 773. 130. 148.]
# 	reward 2.233333333333335
# 	terminated False
# 	truncated False
# 	info {'t': 2.233333333333335}
# step 68
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         764.66666667 130.         148.        ]
# 	reward 2.2666666666666684
# 	terminated False
# 	truncated False
# 	info {'t': 2.2666666666666684}
# step 69
# 	action [False False False]
# 	observation [300.         870.         151.          70.         859.
#  152.          59.         756.33333333 130.         148.        ]
# 	reward 2.3000000000000016
# 	terminated False
# 	truncated False
# 	info {'t': 2.3000000000000016}
# step 70
# 	action [False False False]
# 	observation [300. 870. 151.  70. 859. 152.  59. 748. 130. 148.]
# 	reward 2.333333333333335
# 	terminated False
# 	truncated False
# 	info {'t': 2.333333333333335}
# step 71
# 	action [False False False]
# 	observation [300.         861.66666667 151.          70.         859.
#  152.          59.         739.66666667 130.         148.        ]
# 	reward 2.366666666666668
# 	terminated False
# 	truncated False
# 	info {'t': 2.366666666666668}
# step 72
# 	action [False False False]
# 	observation [300.         853.33333333 151.          70.         859.
#  152.          59.         731.33333333 130.         148.        ]
# 	reward 2.4000000000000012
# 	terminated False
# 	truncated False
# 	info {'t': 2.4000000000000012}
# step 73
# 	action [False False False]
# 	observation [300. 845. 151.  70. 859. 152.  59. 723. 130. 148.]
# 	reward 2.4333333333333345
# 	terminated False
# 	truncated False
# 	info {'t': 2.4333333333333345}
# step 74
# 	action [False False False]
# 	observation [300.         836.66666667 151.          70.         859.
#  152.          59.         714.66666667 130.         148.        ]
# 	reward 2.4666666666666677
# 	terminated False
# 	truncated False
# 	info {'t': 2.4666666666666677}
# step 75
# 	action [False False False]
# 	observation [300.         828.33333333 151.          70.         859.
#  152.          59.         706.33333333 130.         148.        ]
# 	reward 2.500000000000001
# 	terminated False
# 	truncated False
# 	info {'t': 2.500000000000001}
# step 76
# 	action [False False False]
# 	observation [300. 820. 151.  70. 859. 152.  59. 698. 130. 148.]
# 	reward 2.533333333333334
# 	terminated False
# 	truncated False
# 	info {'t': 2.533333333333334}
# step 77
# 	action [False False False]
# 	observation [300.         811.66666667 151.          70.         859.
#  152.          59.         689.66666667 130.         148.        ]
# 	reward 2.5666666666666673
# 	terminated False
# 	truncated False
# 	info {'t': 2.5666666666666673}
# step 78
# 	action [False False False]
# 	observation [300.         803.33333333 151.          70.         859.
#  152.          59.         681.33333333 130.         148.        ]
# 	reward 2.6000000000000005
# 	terminated False
# 	truncated False
# 	info {'t': 2.6000000000000005}
# step 79
# 	action [False False False]
# 	observation [300. 795. 151.  70. 859. 152.  59. 673. 130. 148.]
# 	reward 2.6333333333333337
# 	terminated False
# 	truncated False
# 	info {'t': 2.6333333333333337}
# step 80
# 	action [False False False]
# 	observation [300.         786.66666667 151.          70.         859.
#  152.          59.         664.66666667 130.         148.        ]
# 	reward 2.666666666666667
# 	terminated False
# 	truncated False
# 	info {'t': 2.666666666666667}
# step 81
# 	action [False False False]
# 	observation [300.         778.33333333 151.          70.         859.
#  152.          59.         656.33333333 130.         148.        ]
# 	reward 2.7
# 	terminated False
# 	truncated False
# 	info {'t': 2.7}
# step 82
# 	action [False False False]
# 	observation [300. 770. 151.  70. 859. 152.  59. 648. 130. 148.]
# 	reward 2.7333333333333334
# 	terminated False
# 	truncated False
# 	info {'t': 2.7333333333333334}
# step 83
# 	action [False False False]
# 	observation [300.         761.66666667 151.          70.         859.
#  152.          59.         639.66666667 130.         148.        ]
# 	reward 2.7666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 2.7666666666666666}
# step 84
# 	action [False False False]
# 	observation [300.         753.33333333 151.          70.         859.
#  152.          59.         631.33333333 130.         148.        ]
# 	reward 2.8
# 	terminated False
# 	truncated False
# 	info {'t': 2.8}
# step 85
# 	action [False False False]
# 	observation [300. 745. 151.  70. 859. 152.  59. 623. 130. 148.]
# 	reward 2.833333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 2.833333333333333}
# step 86
# 	action [False False False]
# 	observation [300.         736.66666667 151.          70.         859.
#  152.          59.         614.66666667 130.         148.        ]
# 	reward 2.8666666666666663
# 	terminated False
# 	truncated False
# 	info {'t': 2.8666666666666663}
# step 87
# 	action [False False False]
# 	observation [300.         728.33333333 151.          70.         859.
#  152.          59.         606.33333333 130.         148.        ]
# 	reward 2.8999999999999995
# 	terminated False
# 	truncated False
# 	info {'t': 2.8999999999999995}
# step 88
# 	action [False False False]
# 	observation [300.         720.         151.          70.         850.66666667
#  152.          59.         598.         130.         148.        ]
# 	reward 2.9333333333333327
# 	terminated False
# 	truncated False
# 	info {'t': 2.9333333333333327}
# step 89
# 	action [False False False]
# 	observation [300.         711.66666667 151.          70.         842.33333333
#  152.          59.         589.66666667 130.         148.        ]
# 	reward 2.966666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 2.966666666666666}
# step 90
# 	action [False False False]
# 	observation [300.         703.33333333 151.          70.         834.
#  152.          59.         581.33333333 130.         148.        ]
# 	reward 2.999999999999999
# 	terminated False
# 	truncated False
# 	info {'t': 2.999999999999999}
# step 91
# 	action [False False False]
# 	observation [300.         695.         151.          70.         825.66666667
#  152.          59.         573.         130.         148.        ]
# 	reward 3.0333333333333323
# 	terminated False
# 	truncated False
# 	info {'t': 3.0333333333333323}
# step 92
# 	action [False False False]
# 	observation [300.         686.66666667 151.          70.         817.33333333
#  152.          59.         564.66666667 130.         148.        ]
# 	reward 3.0666666666666655
# 	terminated False
# 	truncated False
# 	info {'t': 3.0666666666666655}
# step 93
# 	action [False False False]
# 	observation [300.         678.33333333 151.          70.         809.
#  152.          59.         556.33333333 130.         148.        ]
# 	reward 3.0999999999999988
# 	terminated False
# 	truncated False
# 	info {'t': 3.0999999999999988}
# step 94
# 	action [False False False]
# 	observation [300.         670.         151.          70.         800.66666667
#  152.          59.         548.         130.         148.        ]
# 	reward 3.133333333333332
# 	terminated False
# 	truncated False
# 	info {'t': 3.133333333333332}
# step 95
# 	action [False False False]
# 	observation [300.         661.66666667 151.          70.         792.33333333
#  152.          59.         539.66666667 130.         148.        ]
# 	reward 3.166666666666665
# 	terminated False
# 	truncated False
# 	info {'t': 3.166666666666665}
# step 96
# 	action [False False False]
# 	observation [300.         653.33333333 151.          70.         784.
#  152.          59.         531.33333333 130.         148.        ]
# 	reward 3.1999999999999984
# 	terminated False
# 	truncated False
# 	info {'t': 3.1999999999999984}
# step 97
# 	action [False False False]
# 	observation [300.         645.         151.          70.         775.66666667
#  152.          59.         523.         130.         148.        ]
# 	reward 3.2333333333333316
# 	terminated False
# 	truncated False
# 	info {'t': 3.2333333333333316}
# step 98
# 	action [False False False]
# 	observation [300.         636.66666667 151.          70.         767.33333333
#  152.          59.         514.66666667 130.         148.        ]
# 	reward 3.266666666666665
# 	terminated False
# 	truncated False
# 	info {'t': 3.266666666666665}
# step 99
# 	action [False False False]
# 	observation [300.         628.33333333 151.          70.         759.
#  152.          59.         506.33333333 130.         148.        ]
# 	reward 3.299999999999998
# 	terminated False
# 	truncated False
# 	info {'t': 3.299999999999998}
# step 100
# 	action [False False False]
# 	observation [300.         620.         151.          70.         750.66666667
#  152.          59.         498.         130.         148.        ]
# 	reward 3.3333333333333313
# 	terminated False
# 	truncated False
# 	info {'t': 3.3333333333333313}
# step 101
# 	action [False False False]
# 	observation [300.         611.66666667 151.          70.         742.33333333
#  152.          59.         489.66666667 130.         148.        ]
# 	reward 3.3666666666666645
# 	terminated False
# 	truncated False
# 	info {'t': 3.3666666666666645}
# step 102
# 	action [False False False]
# 	observation [300.         603.33333333 151.          70.         734.
#  152.          59.         481.33333333 130.         148.        ]
# 	reward 3.3999999999999977
# 	terminated False
# 	truncated False
# 	info {'t': 3.3999999999999977}
# step 103
# 	action [False False False]
# 	observation [300.         595.         151.          70.         725.66666667
#  152.          59.         473.         130.         148.        ]
# 	reward 3.433333333333331
# 	terminated False
# 	truncated False
# 	info {'t': 3.433333333333331}
# step 104
# 	action [False False False]
# 	observation [300.         586.66666667 151.          70.         717.33333333
#  152.          59.         464.66666667 130.         148.        ]
# 	reward 3.466666666666664
# 	terminated False
# 	truncated False
# 	info {'t': 3.466666666666664}
# step 105
# 	action [False False False]
# 	observation [300.         578.33333333 151.          70.         709.
#  152.          59.         456.33333333 130.         148.        ]
# 	reward 3.4999999999999973
# 	terminated False
# 	truncated False
# 	info {'t': 3.4999999999999973}
# step 106
# 	action [False False False]
# 	observation [300.         570.         151.          70.         700.66666667
#  152.          59.         448.         130.         148.        ]
# 	reward 3.5333333333333306
# 	terminated False
# 	truncated False
# 	info {'t': 3.5333333333333306}
# step 107
# 	action [False False False]
# 	observation [300.         561.66666667 151.          70.         692.33333333
#  152.          59.         439.66666667 130.         148.        ]
# 	reward 3.5666666666666638
# 	terminated False
# 	truncated False
# 	info {'t': 3.5666666666666638}
# step 108
# 	action [False False False]
# 	observation [300.         553.33333333 151.          70.         684.
#  152.          59.         431.33333333 130.         148.        ]
# 	reward 3.599999999999997
# 	terminated False
# 	truncated False
# 	info {'t': 3.599999999999997}
# step 109
# 	action [False False False]
# 	observation [300.         545.         151.          70.         675.66666667
#  152.          59.         423.         130.         148.        ]
# 	reward 3.63333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 3.63333333333333}
# step 110
# 	action [False False False]
# 	observation [300.         536.66666667 151.          70.         667.33333333
#  152.          59.         414.66666667 130.         148.        ]
# 	reward 3.6666666666666634
# 	terminated False
# 	truncated False
# 	info {'t': 3.6666666666666634}
# step 111
# 	action [False False False]
# 	observation [300.         528.33333333 151.          70.         659.
#  152.          59.         406.33333333 130.         148.        ]
# 	reward 3.6999999999999966
# 	terminated False
# 	truncated False
# 	info {'t': 3.6999999999999966}
# step 112
# 	action [False False False]
# 	observation [300.         520.         151.          70.         650.66666667
#  152.          59.         398.         130.         148.        ]
# 	reward 3.73333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 3.73333333333333}
# step 113
# 	action [False False False]
# 	observation [300.         511.66666667 151.          70.         642.33333333
#  152.          59.         389.66666667 130.         148.        ]
# 	reward 3.766666666666663
# 	terminated False
# 	truncated False
# 	info {'t': 3.766666666666663}
# step 114
# 	action [False False False]
# 	observation [300.         503.33333333 151.          70.         634.
#  152.          59.         381.33333333 130.         148.        ]
# 	reward 3.7999999999999963
# 	terminated False
# 	truncated False
# 	info {'t': 3.7999999999999963}
# step 115
# 	action [False False False]
# 	observation [300.         495.         151.          70.         625.66666667
#  152.          59.         373.         130.         148.        ]
# 	reward 3.8333333333333295
# 	terminated False
# 	truncated False
# 	info {'t': 3.8333333333333295}
# step 116
# 	action [False False False]
# 	observation [300.         486.66666667 151.          70.         617.33333333
#  152.          59.         364.66666667 130.         148.        ]
# 	reward 3.8666666666666627
# 	terminated False
# 	truncated False
# 	info {'t': 3.8666666666666627}
# step 117
# 	action [False False False]
# 	observation [300.         478.33333333 151.          70.         609.
#  152.          59.         356.33333333 130.         148.        ]
# 	reward 3.899999999999996
# 	terminated False
# 	truncated False
# 	info {'t': 3.899999999999996}
# step 118
# 	action [False False False]
# 	observation [300.         470.         151.          70.         600.66666667
#  152.          59.         348.         130.         148.        ]
# 	reward 3.933333333333329
# 	terminated False
# 	truncated False
# 	info {'t': 3.933333333333329}
# step 119
# 	action [False False False]
# 	observation [300.         461.66666667 151.          70.         592.33333333
#  152.          59.         339.66666667 130.         148.        ]
# 	reward 3.9666666666666623
# 	terminated False
# 	truncated False
# 	info {'t': 3.9666666666666623}
# step 120
# 	action [False False False]
# 	observation [300.         453.33333333 151.          70.         584.
#  152.          59.         331.33333333 130.         148.        ]
# 	reward 3.9999999999999956
# 	terminated False
# 	truncated False
# 	info {'t': 3.9999999999999956}
# step 121
# 	action [False False False]
# 	observation [300.         445.         151.          70.         575.66666667
#  152.          59.         323.         130.         148.        ]
# 	reward 4.033333333333329
# 	terminated False
# 	truncated False
# 	info {'t': 4.033333333333329}
# step 122
# 	action [False False False]
# 	observation [300.         436.66666667 151.          70.         567.33333333
#  152.          59.         314.66666667 130.         148.        ]
# 	reward 4.066666666666662
# 	terminated False
# 	truncated False
# 	info {'t': 4.066666666666662}
# step 123
# 	action [False False False]
# 	observation [300.         428.33333333 151.          70.         559.
#  152.          59.         306.33333333 130.         148.        ]
# 	reward 4.099999999999995
# 	terminated False
# 	truncated False
# 	info {'t': 4.099999999999995}
# step 124
# 	action [False False False]
# 	observation [300.         420.         151.          70.         550.66666667
#  152.          59.         298.         130.         148.        ]
# 	reward 4.133333333333328
# 	terminated False
# 	truncated False
# 	info {'t': 4.133333333333328}
# step 125
# 	action [False False False]
# 	observation [300.         411.66666667 151.          70.         542.33333333
#  152.          59.         289.66666667 130.         148.        ]
# 	reward 4.166666666666662
# 	terminated False
# 	truncated False
# 	info {'t': 4.166666666666662}
# step 126
# 	action [False False False]
# 	observation [300.         403.33333333 151.          70.         534.
#  152.          59.         281.33333333 130.         148.        ]
# 	reward 4.199999999999995
# 	terminated False
# 	truncated False
# 	info {'t': 4.199999999999995}
# step 127
# 	action [False False False]
# 	observation [300.         395.         151.          70.         525.66666667
#  152.          59.         273.         130.         148.        ]
# 	reward 4.233333333333328
# 	terminated False
# 	truncated False
# 	info {'t': 4.233333333333328}
# step 128
# 	action [False False False]
# 	observation [300.         386.66666667 151.          70.         517.33333333
#  152.          59.         264.66666667 130.         148.        ]
# 	reward 4.266666666666661
# 	terminated False
# 	truncated False
# 	info {'t': 4.266666666666661}
# step 129
# 	action [False False False]
# 	observation [300.         378.33333333 151.          70.         509.
#  152.          59.         256.33333333 130.         148.        ]
# 	reward 4.2999999999999945
# 	terminated False
# 	truncated False
# 	info {'t': 4.2999999999999945}
# step 130
# 	action [False False False]
# 	observation [300.         370.         151.          70.         500.66666667
#  152.          59.         248.         130.         148.        ]
# 	reward 4.333333333333328
# 	terminated False
# 	truncated False
# 	info {'t': 4.333333333333328}
# step 131
# 	action [False False False]
# 	observation [300.         361.66666667 151.          70.         492.33333333
#  152.          59.         239.66666667 130.         148.        ]
# 	reward 4.366666666666661
# 	terminated False
# 	truncated False
# 	info {'t': 4.366666666666661}
# step 132
# 	action [False False False]
# 	observation [300.         353.33333333 151.          70.         484.
#  152.          59.         231.33333333 130.         148.        ]
# 	reward 4.399999999999994
# 	terminated False
# 	truncated False
# 	info {'t': 4.399999999999994}
# step 133
# 	action [False False False]
# 	observation [300.         345.         151.          70.         475.66666667
#  152.          59.         223.         130.         148.        ]
# 	reward 4.433333333333327
# 	terminated False
# 	truncated False
# 	info {'t': 4.433333333333327}
# step 134
# 	action [False False False]
# 	observation [300.         336.66666667 151.          70.         467.33333333
#  152.          59.         214.66666667 130.         148.        ]
# 	reward 4.466666666666661
# 	terminated False
# 	truncated False
# 	info {'t': 4.466666666666661}
# step 135
# 	action [False False False]
# 	observation [300.         328.33333333 151.          70.         459.
#  152.          59.         206.33333333 130.         148.        ]
# 	reward 4.499999999999994
# 	terminated False
# 	truncated False
# 	info {'t': 4.499999999999994}
# step 136
# 	action [False False False]
# 	observation [300.         320.         151.          70.         450.66666667
#  152.          59.         198.         130.         148.        ]
# 	reward 4.533333333333327
# 	terminated False
# 	truncated False
# 	info {'t': 4.533333333333327}
# step 137
# 	action [False False False]
# 	observation [300.         311.66666667 151.          70.         442.33333333
#  152.          59.         189.66666667 130.         148.        ]
# 	reward 4.56666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 4.56666666666666}
# step 138
# 	action [False False False]
# 	observation [300.         303.33333333 151.          70.         434.
#  152.          59.         181.33333333 130.         148.        ]
# 	reward 4.599999999999993
# 	terminated False
# 	truncated False
# 	info {'t': 4.599999999999993}
# step 139
# 	action [False False False]
# 	observation [300.         295.         151.          70.         425.66666667
#  152.          59.         173.         130.         148.        ]
# 	reward 4.633333333333327
# 	terminated False
# 	truncated False
# 	info {'t': 4.633333333333327}
# step 140
# 	action [False False False]
# 	observation [300.         286.66666667 151.          70.         417.33333333
#  152.          59.         164.66666667 130.         148.        ]
# 	reward 4.66666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 4.66666666666666}
# step 141
# 	action [False False False]
# 	observation [300.         278.33333333 151.          70.         409.
#  152.          59.         156.33333333 130.         148.        ]
# 	reward 4.699999999999993
# 	terminated False
# 	truncated False
# 	info {'t': 4.699999999999993}
# step 142
# 	action [False False False]
# 	observation [300.         270.         151.          70.         400.66666667
#  152.          59.         148.         130.         148.        ]
# 	reward 4.733333333333326
# 	terminated False
# 	truncated False
# 	info {'t': 4.733333333333326}
# step 143
# 	action [False False False]
# 	observation [300.         261.66666667 151.          70.         392.33333333
#  152.          59.         139.66666667 130.         148.        ]
# 	reward 4.7666666666666595
# 	terminated False
# 	truncated False
# 	info {'t': 4.7666666666666595}
# step 144
# 	action [False False False]
# 	observation [300.         253.33333333 151.          70.         384.
#  152.          59.         131.33333333 130.         148.        ]
# 	reward 4.799999999999993
# 	terminated False
# 	truncated False
# 	info {'t': 4.799999999999993}
# step 145
# 	action [False False False]
# 	observation [300.         245.         151.          70.         375.66666667
#  152.          59.         123.         130.         148.        ]
# 	reward 4.833333333333326
# 	terminated False
# 	truncated False
# 	info {'t': 4.833333333333326}
# step 146
# 	action [False False False]
# 	observation [300.         236.66666667 151.          70.         367.33333333
#  152.          59.         114.66666667 130.         148.        ]
# 	reward 4.866666666666659
# 	terminated False
# 	truncated False
# 	info {'t': 4.866666666666659}
# step 147
# 	action [False False False]
# 	observation [300.         228.33333333 151.          70.         359.
#  152.          59.         106.33333333 130.         148.        ]
# 	reward 4.899999999999992
# 	terminated False
# 	truncated False
# 	info {'t': 4.899999999999992}
# step 148
# 	action [False False False]
# 	observation [300.         220.         151.          70.         350.66666667
#  152.          59.          98.         130.         148.        ]
# 	reward 4.933333333333326
# 	terminated False
# 	truncated False
# 	info {'t': 4.933333333333326}
# step 149
# 	action [False False False]
# 	observation [300.         211.66666667 151.          70.         342.33333333
#  152.          59.          89.66666667 130.         148.        ]
# 	reward 4.966666666666659
# 	terminated False
# 	truncated False
# 	info {'t': 4.966666666666659}
# step 150
# 	action [False  True False]
# 	observation [308.33333333 203.33333333 151.          70.         334.
#  152.          59.          81.33333333 130.         148.        ]
# 	reward 4.999999999999992
# 	terminated False
# 	truncated False
# 	info {'t': 4.999999999999992}
# step 151
# 	action [False  True False]
# 	observation [316.66666667 195.         151.          70.         325.66666667
#  152.          59.          73.         130.         148.        ]
# 	reward 5.033333333333325
# 	terminated False
# 	truncated False
# 	info {'t': 5.033333333333325}
# step 152
# 	action [False  True False]
# 	observation [325.         186.66666667 151.          70.         317.33333333
#  152.          59.          64.66666667 130.         148.        ]
# 	reward 5.066666666666658
# 	terminated False
# 	truncated False
# 	info {'t': 5.066666666666658}
# step 153
# 	action [False  True False]
# 	observation [333.33333333 178.33333333 151.          70.         309.
#  152.          59.          56.33333333 130.         148.        ]
# 	reward 5.099999999999992
# 	terminated False
# 	truncated False
# 	info {'t': 5.099999999999992}
# step 154
# 	action [False  True False]
# 	observation [341.66666667 170.         151.          70.         300.66666667
#  152.          59.          48.         130.         148.        ]
# 	reward 5.133333333333325
# 	terminated False
# 	truncated False
# 	info {'t': 5.133333333333325}
# step 155
# 	action [False  True False]
# 	observation [350.         161.66666667 151.          70.         292.33333333
#  152.          59.          39.66666667 130.         148.        ]
# 	reward 5.166666666666658
# 	terminated False
# 	truncated False
# 	info {'t': 5.166666666666658}
# step 156
# 	action [False  True False]
# 	observation [358.33333333 153.33333333 151.          70.         284.
#  152.          59.          31.33333333 130.         148.        ]
# 	reward 5.199999999999991
# 	terminated False
# 	truncated False
# 	info {'t': 5.199999999999991}
# step 157
# 	action [False False False]
# 	observation [358.33333333 145.         151.          70.         275.66666667
#  152.          59.          23.         130.         148.        ]
# 	reward 5.2333333333333245
# 	terminated False
# 	truncated False
# 	info {'t': 5.2333333333333245}
# step 158
# 	action [False False False]
# 	observation [358.33333333 136.66666667 151.          70.         267.33333333
#  152.          59.          14.66666667 130.         148.        ]
# 	reward 5.266666666666658
# 	terminated False
# 	truncated False
# 	info {'t': 5.266666666666658}
# step 159
# 	action [False False False]
# 	observation [358.33333333 128.33333333 151.          70.         259.
#  152.          59.           6.33333333 130.         148.        ]
# 	reward 5.299999999999991
# 	terminated False
# 	truncated False
# 	info {'t': 5.299999999999991}
# step 160
# 	action [False False False]
# 	observation [358.33333333 120.         151.          70.         250.66666667
#  152.          59.          -2.         130.         148.        ]
# 	reward 5.333333333333324
# 	terminated False
# 	truncated False
# 	info {'t': 5.333333333333324}
# step 161
# 	action [False False False]
# 	observation [358.33333333 111.66666667 151.          70.         242.33333333
#  152.          59.         -10.33333333 130.         148.        ]
# 	reward 5.366666666666657
# 	terminated False
# 	truncated False
# 	info {'t': 5.366666666666657}
# step 162
# 	action [False False False]
# 	observation [358.33333333 103.33333333 151.          70.         234.
#  152.          59.         -18.66666667 130.         148.        ]
# 	reward 5.399999999999991
# 	terminated False
# 	truncated False
# 	info {'t': 5.399999999999991}
# step 163
# 	action [False False False]
# 	observation [358.33333333  95.         151.          70.         225.66666667
#  152.          59.         -27.         130.         148.        ]
# 	reward 5.433333333333324
# 	terminated False
# 	truncated False
# 	info {'t': 5.433333333333324}
# step 164
# 	action [False False False]
# 	observation [358.33333333  86.66666667 151.          70.         217.33333333
#  152.          59.         -35.33333333 130.         148.        ]
# 	reward 5.466666666666657
# 	terminated False
# 	truncated False
# 	info {'t': 5.466666666666657}
# step 165
# 	action [False False False]
# 	observation [358.33333333  78.33333333 151.          70.         209.
#  152.          59.         -43.66666667 130.         148.        ]
# 	reward 5.49999999999999
# 	terminated False
# 	truncated False
# 	info {'t': 5.49999999999999}
# step 166
# 	action [False False False]
# 	observation [358.33333333  70.         151.          70.         200.66666667
#  152.          59.         -52.         130.         148.        ]
# 	reward 5.5333333333333234
# 	terminated False
# 	truncated False
# 	info {'t': 5.5333333333333234}
# step 167
# 	action [False False False]
# 	observation [358.33333333  61.66666667 151.          70.         192.33333333
#  152.          59.         -60.33333333 130.         148.        ]
# 	reward 5.566666666666657
# 	terminated False
# 	truncated False
# 	info {'t': 5.566666666666657}
# step 168
# 	action [False False False]
# 	observation [358.33333333  53.33333333 151.          70.         184.
#  152.          59.         -68.66666667 130.         148.        ]
# 	reward 5.59999999999999
# 	terminated False
# 	truncated False
# 	info {'t': 5.59999999999999}
# step 169
# 	action [False False False]
# 	observation [358.33333333  45.         151.          70.         175.66666667
#  152.          59.         -77.         130.         148.        ]
# 	reward 5.633333333333323
# 	terminated False
# 	truncated False
# 	info {'t': 5.633333333333323}
# step 170
# 	action [False False False]
# 	observation [358.33333333  36.66666667 151.          70.         167.33333333
#  152.          59.         -85.33333333 130.         148.        ]
# 	reward 5.666666666666656
# 	terminated False
# 	truncated False
# 	info {'t': 5.666666666666656}
# step 171
# 	action [False False False]
# 	observation [358.33333333  28.33333333 151.          70.         159.
#  152.          59.         -93.66666667 130.         148.        ]
# 	reward 5.6999999999999895
# 	terminated False
# 	truncated False
# 	info {'t': 5.6999999999999895}
# step 172
# 	action [ True False False]
# 	observation [ 350.           20.          151.           70.          150.66666667
#   152.           59.         -102.          130.          148.        ]
# 	reward 5.733333333333323
# 	terminated False
# 	truncated False
# 	info {'t': 5.733333333333323}
# step 173
# 	action [ True False False]
# 	observation [ 341.66666667   11.66666667  151.           70.          142.33333333
#   152.           59.         -110.33333333  130.          148.        ]
# 	reward 5.766666666666656
# 	terminated False
# 	truncated False
# 	info {'t': 5.766666666666656}
# step 174
# 	action [ True False False]
# 	observation [ 333.33333333    3.33333333  151.           70.          134.
#   152.           59.         -118.66666667  130.          148.        ]
# 	reward 5.799999999999989
# 	terminated False
# 	truncated False
# 	info {'t': 5.799999999999989}
# step 175
# 	action [ True False False]
# 	observation [ 325.           -5.          151.           70.          125.66666667
#   152.           59.         -127.          130.          148.        ]
# 	reward 5.833333333333322
# 	terminated False
# 	truncated False
# 	info {'t': 5.833333333333322}
# step 176
# 	action [ True False False]
# 	observation [ 316.66666667  -13.33333333  151.           70.          117.33333333
#   152.           59.         -135.33333333  130.          148.        ]
# 	reward 5.866666666666656
# 	terminated False
# 	truncated False
# 	info {'t': 5.866666666666656}
# step 177
# 	action [ True False False]
# 	observation [ 308.33333333  -21.66666667  151.           70.          109.
#   152.           59.         -143.66666667  130.          148.        ]
# 	reward 5.899999999999989
# 	terminated False
# 	truncated False
# 	info {'t': 5.899999999999989}
# step 178
# 	action [ True False False]
# 	observation [ 300.          -30.          151.           70.          100.66666667
#   152.           59.         -152.          130.          148.        ]
# 	reward 5.933333333333322
# 	terminated False
# 	truncated False
# 	info {'t': 5.933333333333322}
# step 179
# 	action [ True False False]
# 	observation [ 291.66666667  -38.33333333  151.           70.           92.33333333
#   152.           59.         -160.33333333  130.          148.        ]
# 	reward 5.966666666666655
# 	terminated False
# 	truncated False
# 	info {'t': 5.966666666666655}
# step 180
# 	action [ True False False]
# 	observation [ 283.33333333  -46.66666667  151.           70.           84.
#   152.           59.         -168.66666667  130.          148.        ]
# 	reward 5.9999999999999885
# 	terminated False
# 	truncated False
# 	info {'t': 5.9999999999999885}
# step 181
# 	action [False  True False]
# 	observation [ 291.66666667  -55.          151.           70.           75.66666667
#   152.           59.         -177.          130.          148.        ]
# 	reward 6.033333333333322
# 	terminated False
# 	truncated False
# 	info {'t': 6.033333333333322}
# step 182
# 	action [False  True False]
# 	observation [ 300.          -63.33333333  151.           70.           67.33333333
#   152.           59.         -185.33333333  130.          148.        ]
# 	reward 6.066666666666655
# 	terminated False
# 	truncated False
# 	info {'t': 6.066666666666655}
# step 183
# 	action [False  True False]
# 	observation [ 308.33333333  -71.66666667  151.           70.           59.
#   152.           59.         -193.66666667  130.          148.        ]
# 	reward 6.099999999999988
# 	terminated False
# 	truncated False
# 	info {'t': 6.099999999999988}
# step 184
# 	action [False  True False]
# 	observation [ 316.66666667  -80.          151.           70.           50.66666667
#   152.           59.         -202.          130.          148.        ]
# 	reward 6.133333333333321
# 	terminated False
# 	truncated False
# 	info {'t': 6.133333333333321}
# step 185
# 	action [False  True False]
# 	observation [ 325.          -88.33333333  151.           70.           42.33333333
#   152.           59.         -210.33333333  130.          148.        ]
# 	reward 6.1666666666666545
# 	terminated False
# 	truncated False
# 	info {'t': 6.1666666666666545}
# step 186
# 	action [False  True False]
# 	observation [ 333.33333333  -96.66666667  151.           70.           34.
#   152.           59.         -218.66666667  130.          148.        ]
# 	reward 6.199999999999988
# 	terminated False
# 	truncated False
# 	info {'t': 6.199999999999988}
# step 187
# 	action [False  True False]
# 	observation [ 341.66666667 -105.          151.           70.           25.66666667
#   152.           59.         -227.          130.          148.        ]
# 	reward 6.233333333333321
# 	terminated False
# 	truncated False
# 	info {'t': 6.233333333333321}
# step 188
# 	action [False  True False]
# 	observation [ 350.         -113.33333333  151.           70.           17.33333333
#   152.           59.         -235.33333333  130.          148.        ]
# 	reward 6.266666666666654
# 	terminated False
# 	truncated False
# 	info {'t': 6.266666666666654}
# step 189
# 	action [False  True False]
# 	observation [ 358.33333333 -121.66666667  151.           70.            9.
#   152.           59.         -243.66666667  130.          148.        ]
# 	reward 6.299999999999987
# 	terminated False
# 	truncated False
# 	info {'t': 6.299999999999987}
# step 190
# 	action [False  True False]
# ...
#  536.         140.         671.66666667  67.          55.        ]
# 	reward 7.266666666666651
# 	terminated False
# 	truncated False
# 	info {'t': 7.266666666666651}
# step 219
# 	action [False  True False]
# 	observation [250.         664.         439.          89.         823.33333333
#  536.         140.         663.33333333  67.          55.        ]
# 	reward 7.299999999999984
# 	terminated False
# 	truncated False
# 	info {'t': 7.299999999999984}
# step 220
# 	action [False  True False]
# 	observation [258.33333333 655.66666667 439.          89.         815.
#  536.         140.         655.          67.          55.        ]
# 	reward 7.333333333333317
# 	terminated False
# 	truncated False
# 	info {'t': 7.333333333333317}
# step 221
# 	action [False  True False]
# 	observation [266.66666667 647.33333333 439.          89.         806.66666667
#  536.         140.         646.66666667  67.          55.        ]
# 	reward 7.36666666666665
# 	terminated False
# 	truncated False
# 	info {'t': 7.36666666666665}
# step 222
# 	action [False  True False]
# 	observation [275.         639.         439.          89.         798.33333333
#  536.         140.         638.33333333  67.          55.        ]
# 	reward 7.3999999999999835
# 	terminated False
# 	truncated False
# 	info {'t': 7.3999999999999835}
# step 223
# 	action [False  True False]
# 	observation [283.33333333 630.66666667 439.          89.         790.
#  536.         140.         630.          67.          55.        ]
# 	reward 7.433333333333317
# 	terminated False
# 	truncated False
# 	info {'t': 7.433333333333317}
# step 224
# 	action [False  True False]
# 	observation [291.66666667 622.33333333 439.          89.         781.66666667
#  536.         140.         621.66666667  67.          55.        ]
# 	reward 7.46666666666665
# 	terminated False
# 	truncated False
# 	info {'t': 7.46666666666665}
# step 225
# 	action [False  True False]
# 	observation [300.         614.         439.          89.         773.33333333
#  536.         140.         613.33333333  67.          55.        ]
# 	reward 7.499999999999983
# 	terminated False
# 	truncated False
# 	info {'t': 7.499999999999983}
# step 226
# 	action [False  True False]
# 	observation [308.33333333 605.66666667 439.          89.         765.
#  536.         140.         605.          67.          55.        ]
# 	reward 7.533333333333316
# 	terminated False
# 	truncated False
# 	info {'t': 7.533333333333316}
# step 227
# 	action [False  True False]
# 	observation [316.66666667 597.33333333 439.          89.         756.66666667
#  536.         140.         596.66666667  67.          55.        ]
# 	reward 7.5666666666666496
# 	terminated False
# 	truncated False
# 	info {'t': 7.5666666666666496}
# step 228
# 	action [False  True False]
# 	observation [325.         589.         439.          89.         748.33333333
#  536.         140.         588.33333333  67.          55.        ]
# 	reward 7.599999999999983
# 	terminated False
# 	truncated False
# 	info {'t': 7.599999999999983}
# step 229
# 	action [False  True False]
# 	observation [333.33333333 580.66666667 439.          89.         740.
#  536.         140.         580.          67.          55.        ]
# 	reward 7.633333333333316
# 	terminated False
# 	truncated False
# 	info {'t': 7.633333333333316}
# step 230
# 	action [False  True False]
# 	observation [341.66666667 572.33333333 439.          89.         731.66666667
#  536.         140.         571.66666667  67.          55.        ]
# 	reward 7.666666666666649
# 	terminated False
# 	truncated False
# 	info {'t': 7.666666666666649}
# step 231
# 	action [False  True False]
# 	observation [350.         564.         439.          89.         723.33333333
#  536.         140.         563.33333333  67.          55.        ]
# 	reward 7.699999999999982
# 	terminated False
# 	truncated False
# 	info {'t': 7.699999999999982}
# step 232
# 	action [False  True False]
# 	observation [358.33333333 555.66666667 439.          89.         715.
#  536.         140.         555.          67.          55.        ]
# 	reward 7.733333333333316
# 	terminated False
# 	truncated False
# 	info {'t': 7.733333333333316}
# step 233
# 	action [False  True False]
# 	observation [366.66666667 547.33333333 439.          89.         706.66666667
#  536.         140.         546.66666667  67.          55.        ]
# 	reward 7.766666666666649
# 	terminated False
# 	truncated False
# 	info {'t': 7.766666666666649}
# step 234
# 	action [False  True False]
# 	observation [375.         539.         439.          89.         698.33333333
#  536.         140.         538.33333333  67.          55.        ]
# 	reward 7.799999999999982
# 	terminated False
# 	truncated False
# 	info {'t': 7.799999999999982}
# step 235
# 	action [False  True False]
# 	observation [383.33333333 530.66666667 439.          89.         690.
#  536.         140.         530.          67.          55.        ]
# 	reward 7.833333333333315
# 	terminated False
# 	truncated False
# 	info {'t': 7.833333333333315}
# step 236
# 	action [False  True False]
# 	observation [391.66666667 522.33333333 439.          89.         681.66666667
#  536.         140.         521.66666667  67.          55.        ]
# 	reward 7.8666666666666485
# 	terminated False
# 	truncated False
# 	info {'t': 7.8666666666666485}
# step 237
# 	action [False  True False]
# 	observation [400.         514.         439.          89.         673.33333333
#  536.         140.         513.33333333  67.          55.        ]
# 	reward 7.899999999999982
# 	terminated False
# 	truncated False
# 	info {'t': 7.899999999999982}
# step 238
# 	action [False  True False]
# 	observation [408.33333333 505.66666667 439.          89.         665.
#  536.         140.         505.          67.          55.        ]
# 	reward 7.933333333333315
# 	terminated False
# 	truncated False
# 	info {'t': 7.933333333333315}
# step 239
# 	action [False False False]
# 	observation [408.33333333 497.33333333 439.          89.         656.66666667
#  536.         140.         496.66666667  67.          55.        ]
# 	reward 7.966666666666648
# 	terminated False
# 	truncated False
# 	info {'t': 7.966666666666648}
# step 240
# 	action [ True False False]
# 	observation [400.         489.         439.          89.         648.33333333
#  536.         140.         488.33333333  67.          55.        ]
# 	reward 7.999999999999981
# 	terminated False
# 	truncated False
# 	info {'t': 7.999999999999981}
# step 241
# 	action [ True False False]
# 	observation [391.66666667 480.66666667 439.          89.         640.
#  536.         140.         480.          67.          55.        ]
# 	reward 8.033333333333315
# 	terminated False
# 	truncated False
# 	info {'t': 8.033333333333315}
# step 242
# 	action [ True False False]
# 	observation [383.33333333 472.33333333 439.          89.         631.66666667
#  536.         140.         471.66666667  67.          55.        ]
# 	reward 8.066666666666649
# 	terminated False
# 	truncated False
# 	info {'t': 8.066666666666649}
# step 243
# 	action [False False False]
# 	observation [383.33333333 464.         439.          89.         623.33333333
#  536.         140.         463.33333333  67.          55.        ]
# 	reward 8.099999999999982
# 	terminated False
# 	truncated False
# 	info {'t': 8.099999999999982}
# step 244
# 	action [False False False]
# 	observation [383.33333333 455.66666667 439.          89.         615.
#  536.         140.         455.          67.          55.        ]
# 	reward 8.133333333333315
# 	terminated False
# 	truncated False
# 	info {'t': 8.133333333333315}
# step 245
# 	action [False False False]
# 	observation [383.33333333 447.33333333 439.          89.         606.66666667
#  536.         140.         446.66666667  67.          55.        ]
# 	reward 8.166666666666648
# 	terminated False
# 	truncated False
# 	info {'t': 8.166666666666648}
# step 246
# 	action [False False False]
# 	observation [383.33333333 439.         439.          89.         598.33333333
#  536.         140.         438.33333333  67.          55.        ]
# 	reward 8.199999999999982
# 	terminated False
# 	truncated False
# 	info {'t': 8.199999999999982}
# step 247
# 	action [False False False]
# 	observation [383.33333333 430.66666667 439.          89.         590.
#  536.         140.         430.          67.          55.        ]
# 	reward 8.233333333333315
# 	terminated False
# 	truncated False
# 	info {'t': 8.233333333333315}
# step 248
# 	action [False False False]
# 	observation [383.33333333 422.33333333 439.          89.         581.66666667
#  536.         140.         421.66666667  67.          55.        ]
# 	reward 8.266666666666648
# 	terminated False
# 	truncated False
# 	info {'t': 8.266666666666648}
# step 249
# 	action [False False False]
# 	observation [383.33333333 414.         439.          89.         573.33333333
#  536.         140.         413.33333333  67.          55.        ]
# 	reward 8.299999999999981
# 	terminated False
# 	truncated False
# 	info {'t': 8.299999999999981}
# step 250
# 	action [False False False]
# 	observation [383.33333333 405.66666667 439.          89.         565.
#  536.         140.         405.          67.          55.        ]
# 	reward 8.333333333333314
# 	terminated False
# 	truncated False
# 	info {'t': 8.333333333333314}
# step 251
# 	action [False False False]
# 	observation [383.33333333 397.33333333 439.          89.         556.66666667
#  536.         140.         396.66666667  67.          55.        ]
# 	reward 8.366666666666648
# 	terminated False
# 	truncated False
# 	info {'t': 8.366666666666648}
# step 252
# 	action [False False False]
# 	observation [383.33333333 389.         439.          89.         548.33333333
#  536.         140.         388.33333333  67.          55.        ]
# 	reward 8.39999999999998
# 	terminated False
# 	truncated False
# 	info {'t': 8.39999999999998}
# step 253
# 	action [False False False]
# 	observation [383.33333333 380.66666667 439.          89.         540.
#  536.         140.         380.          67.          55.        ]
# 	reward 8.433333333333314
# 	terminated False
# 	truncated False
# 	info {'t': 8.433333333333314}
# step 254
# 	action [False False False]
# 	observation [383.33333333 372.33333333 439.          89.         531.66666667
#  536.         140.         371.66666667  67.          55.        ]
# 	reward 8.466666666666647
# 	terminated False
# 	truncated False
# 	info {'t': 8.466666666666647}
# step 255
# 	action [False False False]
# 	observation [383.33333333 364.         439.          89.         523.33333333
#  536.         140.         363.33333333  67.          55.        ]
# 	reward 8.49999999999998
# 	terminated False
# 	truncated False
# 	info {'t': 8.49999999999998}
# step 256
# 	action [False False False]
# 	observation [383.33333333 355.66666667 439.          89.         515.
#  536.         140.         355.          67.          55.        ]
# 	reward 8.533333333333314
# 	terminated False
# 	truncated False
# 	info {'t': 8.533333333333314}
# step 257
# 	action [False False False]
# 	observation [383.33333333 347.33333333 439.          89.         506.66666667
#  536.         140.         346.66666667  67.          55.        ]
# 	reward 8.566666666666647
# 	terminated False
# 	truncated False
# 	info {'t': 8.566666666666647}
# step 258
# 	action [False False False]
# 	observation [383.33333333 339.         439.          89.         498.33333333
#  536.         140.         338.33333333  67.          55.        ]
# 	reward 8.59999999999998
# 	terminated False
# 	truncated False
# 	info {'t': 8.59999999999998}
# step 259
# 	action [False False False]
# 	observation [383.33333333 330.66666667 439.          89.         490.
#  536.         140.         330.          67.          55.        ]
# 	reward 8.633333333333313
# 	terminated False
# 	truncated False
# 	info {'t': 8.633333333333313}
# step 260
# 	action [False False False]
# 	observation [383.33333333 322.33333333 439.          89.         481.66666667
#  536.         140.         321.66666667  67.          55.        ]
# 	reward 8.666666666666647
# 	terminated False
# 	truncated False
# 	info {'t': 8.666666666666647}
# step 261
# 	action [False False False]
# 	observation [383.33333333 314.         439.          89.         473.33333333
#  536.         140.         313.33333333  67.          55.        ]
# 	reward 8.69999999999998
# 	terminated False
# 	truncated False
# 	info {'t': 8.69999999999998}
# step 262
# 	action [False False False]
# 	observation [383.33333333 305.66666667 439.          89.         465.
#  536.         140.         305.          67.          55.        ]
# 	reward 8.733333333333313
# 	terminated False
# 	truncated False
# 	info {'t': 8.733333333333313}
# step 263
# 	action [False False False]
# 	observation [383.33333333 297.33333333 439.          89.         456.66666667
#  536.         140.         296.66666667  67.          55.        ]
# 	reward 8.766666666666646
# 	terminated False
# 	truncated False
# 	info {'t': 8.766666666666646}
# step 264
# 	action [False False False]
# 	observation [383.33333333 289.         439.          89.         448.33333333
#  536.         140.         288.33333333  67.          55.        ]
# 	reward 8.79999999999998
# 	terminated False
# 	truncated False
# 	info {'t': 8.79999999999998}
# step 265
# 	action [False False False]
# 	observation [383.33333333 280.66666667 439.          89.         440.
#  536.         140.         280.          67.          55.        ]
# 	reward 8.833333333333313
# 	terminated False
# 	truncated False
# 	info {'t': 8.833333333333313}
# step 266
# 	action [False False False]
# 	observation [383.33333333 272.33333333 439.          89.         431.66666667
#  536.         140.         271.66666667  67.          55.        ]
# 	reward 8.866666666666646
# 	terminated False
# 	truncated False
# 	info {'t': 8.866666666666646}
# step 267
# 	action [False False False]
# 	observation [383.33333333 264.         439.          89.         423.33333333
#  536.         140.         263.33333333  67.          55.        ]
# 	reward 8.899999999999979
# 	terminated False
# 	truncated False
# 	info {'t': 8.899999999999979}
# step 268
# 	action [False False False]
# 	observation [383.33333333 255.66666667 439.          89.         415.
#  536.         140.         255.          67.          55.        ]
# 	reward 8.933333333333312
# 	terminated False
# 	truncated False
# 	info {'t': 8.933333333333312}
# step 269
# 	action [False False False]
# 	observation [383.33333333 247.33333333 439.          89.         406.66666667
#  536.         140.         246.66666667  67.          55.        ]
# 	reward 8.966666666666645
# 	terminated False
# 	truncated False
# 	info {'t': 8.966666666666645}
# step 270
# 	action [False False False]
# 	observation [383.33333333 239.         439.          89.         398.33333333
#  536.         140.         238.33333333  67.          55.        ]
# 	reward 8.999999999999979
# 	terminated False
# 	truncated False
# 	info {'t': 8.999999999999979}
# step 271
# 	action [False False False]
# 	observation [383.33333333 230.66666667 439.          89.         390.
#  536.         140.         230.          67.          55.        ]
# 	reward 9.033333333333312
# 	terminated False
# 	truncated False
# 	info {'t': 9.033333333333312}
# step 272
# 	action [False False False]
# 	observation [383.33333333 222.33333333 439.          89.         381.66666667
#  536.         140.         221.66666667  67.          55.        ]
# 	reward 9.066666666666645
# 	terminated False
# 	truncated False
# 	info {'t': 9.066666666666645}
# step 273
# 	action [False False False]
# 	observation [383.33333333 214.         439.          89.         373.33333333
#  536.         140.         213.33333333  67.          55.        ]
# 	reward 9.099999999999978
# 	terminated False
# 	truncated False
# 	info {'t': 9.099999999999978}
# step 274
# 	action [False False False]
# 	observation [383.33333333 205.66666667 439.          89.         365.
#  536.         140.         205.          67.          55.        ]
# 	reward 9.133333333333312
# 	terminated False
# 	truncated False
# 	info {'t': 9.133333333333312}
# step 275
# 	action [False False False]
# 	observation [383.33333333 197.33333333 439.          89.         356.66666667
#  536.         140.         196.66666667  67.          55.        ]
# 	reward 9.166666666666645
# 	terminated False
# 	truncated False
# 	info {'t': 9.166666666666645}
# step 276
# 	action [False False False]
# 	observation [383.33333333 189.         439.          89.         348.33333333
#  536.         140.         188.33333333  67.          55.        ]
# 	reward 9.199999999999978
# 	terminated True
# 	truncated False
# 	info {'t': 9.199999999999978}
# Total reward 1274.199999999998

# %%
env = gym.make("AsteroidEnv-v0", render_mode="rgb_array", max_episode_steps=10000)
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=100_000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\Charles Henri\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\utils\passive_env_checker.py:135: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# c:\Users\Charles Henri\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\utils\passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# c:\Users\Charles Henri\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\utils\passive_env_checker.py:135: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# c:\Users\Charles Henri\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\utils\passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# -----------------------------
# | time/              |      |
# |    fps             | 1612 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.65e+03    |
# |    ep_rew_mean          | 2.22e+05    |
# | time/                   |             |
# |    fps                  | 1041        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009591398 |
# |    clip_fraction        | 0.0205      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.05e+05    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00339    |
# |    value_loss           | 4.26e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.48e+03     |
# |    ep_rew_mean          | 1.25e+05     |
# | time/                   |              |
# |    fps                  | 939          |
# |    iterations           | 3            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0012930572 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.07        |
# |    explained_variance   | -0.00187     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14e+06     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 2e+06        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.17e+03     |
# |    ep_rew_mean          | 9.69e+04     |
# | time/                   |              |
# |    fps                  | 906          |
# |    iterations           | 4            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0070161144 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.06        |
# |    explained_variance   | -0.000418    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.22e+04     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00378     |
# |    value_loss           | 1.87e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.19e+03     |
# |    ep_rew_mean          | 9.35e+04     |
# | time/                   |              |
# |    fps                  | 891          |
# |    iterations           | 5            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0064234626 |
# |    clip_fraction        | 0.00635      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.05        |
# |    explained_variance   | -3.36e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.59e+05     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 3.3e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.2e+03      |
# |    ep_rew_mean          | 9.19e+04     |
# | time/                   |              |
# |    fps                  | 882          |
# |    iterations           | 6            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0056713633 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.05        |
# |    explained_variance   | -2.42e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.27e+05     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00334     |
# |    value_loss           | 4.73e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.06e+03     |
# |    ep_rew_mean          | 8.18e+04     |
# | time/                   |              |
# |    fps                  | 876          |
# |    iterations           | 7            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0037660794 |
# |    clip_fraction        | 0.00283      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.05        |
# |    explained_variance   | -6.91e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.32e+05     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 5.05e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12e+03    |
# |    ep_rew_mean          | 8.43e+04    |
# | time/                   |             |
# |    fps                  | 873         |
# |    iterations           | 8           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010443579 |
# |    clip_fraction        | 0.000391    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74e+05    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00235    |
# |    value_loss           | 3.83e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.1e+03      |
# |    ep_rew_mean          | 8.17e+04     |
# | time/                   |              |
# |    fps                  | 872          |
# |    iterations           | 9            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0051073562 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.01        |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.54e+05     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 5.22e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.12e+03     |
# |    ep_rew_mean          | 8.23e+04     |
# | time/                   |              |
# |    fps                  | 873          |
# |    iterations           | 10           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0064602504 |
# |    clip_fraction        | 0.0362       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.98        |
# |    explained_variance   | -0.000124    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.05e+05     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00658     |
# |    value_loss           | 3.89e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.17e+03     |
# |    ep_rew_mean          | 8.61e+04     |
# | time/                   |              |
# |    fps                  | 872          |
# |    iterations           | 11           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0076042325 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.02        |
# |    explained_variance   | -3.58e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.38e+05     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00515     |
# |    value_loss           | 4.92e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.21e+03     |
# |    ep_rew_mean          | 8.86e+04     |
# | time/                   |              |
# |    fps                  | 871          |
# |    iterations           | 12           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0029378368 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.03        |
# |    explained_variance   | -4.85e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.17e+05     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00245     |
# |    value_loss           | 8.3e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.12e+03     |
# |    ep_rew_mean          | 8.28e+04     |
# | time/                   |              |
# |    fps                  | 870          |
# |    iterations           | 13           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0017347005 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.04        |
# |    explained_variance   | -9.66e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.86e+05     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00262     |
# |    value_loss           | 8.43e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06e+03    |
# |    ep_rew_mean          | 7.86e+04    |
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 14          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004861572 |
# |    clip_fraction        | 0.0064      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 3.81e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.81e+04    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00137    |
# |    value_loss           | 1.36e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06e+03    |
# |    ep_rew_mean          | 7.83e+04    |
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 15          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010429962 |
# |    clip_fraction        | 0.0311      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 1.97e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.55e+05    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00476    |
# |    value_loss           | 3.72e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09e+03    |
# |    ep_rew_mean          | 8.02e+04    |
# | time/                   |             |
# |    fps                  | 868         |
# |    iterations           | 16          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006301407 |
# |    clip_fraction        | 0.0082      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | -3.34e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.22e+05    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00239    |
# |    value_loss           | 4.05e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11e+03    |
# |    ep_rew_mean          | 8.1e+04     |
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 17          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.002987937 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | -4.65e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.18e+05    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00307    |
# |    value_loss           | 5.84e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.06e+03     |
# |    ep_rew_mean          | 7.77e+04     |
# | time/                   |              |
# |    fps                  | 867          |
# |    iterations           | 18           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0054330304 |
# |    clip_fraction        | 0.00967      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.97        |
# |    explained_variance   | -7.15e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.01e+05     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00379     |
# |    value_loss           | 5.55e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08e+03    |
# |    ep_rew_mean          | 7.87e+04    |
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 19          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007471394 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51e+05    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00611    |
# |    value_loss           | 3.51e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.05e+03     |
# |    ep_rew_mean          | 7.71e+04     |
# | time/                   |              |
# |    fps                  | 867          |
# |    iterations           | 20           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0057765143 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.03        |
# |    explained_variance   | -2.03e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.52e+05     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00386     |
# |    value_loss           | 4.95e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.08e+03     |
# |    ep_rew_mean          | 7.85e+04     |
# | time/                   |              |
# |    fps                  | 865          |
# |    iterations           | 21           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0068937377 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.96        |
# |    explained_variance   | 4.59e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.04e+05     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00385     |
# |    value_loss           | 3.73e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09e+03    |
# |    ep_rew_mean          | 7.88e+04    |
# | time/                   |             |
# |    fps                  | 864         |
# |    iterations           | 22          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004556349 |
# |    clip_fraction        | 0.0115      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | -3.46e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.09e+05    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00427    |
# |    value_loss           | 5.61e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06e+03    |
# |    ep_rew_mean          | 7.72e+04    |
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 23          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008299361 |
# |    clip_fraction        | 0.0151      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | -1.55e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.54e+05    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00521    |
# |    value_loss           | 4.8e+05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | 7.61e+04    |
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 24          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008631632 |
# |    clip_fraction        | 0.0318      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.8e+05     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 3.19e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.05e+03     |
# |    ep_rew_mean          | 7.59e+04     |
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 25           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0077806236 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.06e+05     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00328     |
# |    value_loss           | 3.77e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09e+03    |
# |    ep_rew_mean          | 7.89e+04    |
# | time/                   |             |
# |    fps                  | 862         |
# |    iterations           | 26          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008609783 |
# |    clip_fraction        | 0.00513     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.73e+05    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 3.86e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.06e+03     |
# |    ep_rew_mean          | 7.7e+04      |
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 27           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0055275448 |
# |    clip_fraction        | 0.00581      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.5e+05      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00343     |
# |    value_loss           | 9.93e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | 7.61e+04    |
# | time/                   |             |
# |    fps                  | 862         |
# |    iterations           | 28          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009396743 |
# |    clip_fraction        | 0.0111      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | -7.15e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.76e+05    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0026     |
# |    value_loss           | 2.85e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.07e+03     |
# |    ep_rew_mean          | 7.72e+04     |
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 29           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0071326247 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.9e+05      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0047      |
# |    value_loss           | 3.73e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+03    |
# |    ep_rew_mean          | 7.68e+04    |
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 30          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.014654633 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.52e+05    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0076     |
# |    value_loss           | 5.41e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08e+03    |
# |    ep_rew_mean          | 7.77e+04    |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 31          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.003943697 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.96e+05    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00347    |
# |    value_loss           | 3.7e+05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08e+03    |
# |    ep_rew_mean          | 7.73e+04    |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 32          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.001275985 |
# |    clip_fraction        | 0.00171     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | -7.15e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.89e+05    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00282    |
# |    value_loss           | 6.04e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08e+03    |
# |    ep_rew_mean          | 7.71e+04    |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 33          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004570871 |
# |    clip_fraction        | 0.000879    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.73e+05    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00282    |
# |    value_loss           | 3.59e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.06e+03     |
# |    ep_rew_mean          | 7.57e+04     |
# | time/                   |              |
# |    fps                  | 860          |
# |    iterations           | 34           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0028255645 |
# |    clip_fraction        | 0.00112      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.75e+05     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 3.93e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.06e+03     |
# |    ep_rew_mean          | 7.57e+04     |
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 35           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0045201126 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.86        |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.64e+05     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000835    |
# |    value_loss           | 3.11e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.07e+03     |
# |    ep_rew_mean          | 7.63e+04     |
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 36           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0009172631 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.01e+05     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 3.88e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | 7.52e+04    |
# | time/                   |             |
# |    fps                  | 858         |
# |    iterations           | 37          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008800664 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.53e+05    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00507    |
# |    value_loss           | 5.12e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+03    |
# |    ep_rew_mean          | 7.63e+04    |
# | time/                   |             |
# |    fps                  | 858         |
# |    iterations           | 38          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.016067104 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.72e+05    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0049     |
# |    value_loss           | 3.52e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.05e+03     |
# |    ep_rew_mean          | 7.52e+04     |
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 39           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0081048235 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.09e+05     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00579     |
# |    value_loss           | 6.09e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.05e+03     |
# |    ep_rew_mean          | 7.53e+04     |
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 40           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0020956858 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.82        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.51e+05     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000664    |
# |    value_loss           | 3.48e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.06e+03     |
# |    ep_rew_mean          | 7.59e+04     |
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 41           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0038975326 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.11e+05     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 3.85e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08e+03    |
# |    ep_rew_mean          | 7.68e+04    |
# | time/                   |             |
# |    fps                  | 859         |
# |    iterations           | 42          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.005438396 |
# |    clip_fraction        | 0.0189      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | -5.96e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.68e+05    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 5.17e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.05e+03     |
# |    ep_rew_mean          | 7.55e+04     |
# | time/                   |              |
# |    fps                  | 858          |
# |    iterations           | 43           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0058582937 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.5e+05      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00561     |
# |    value_loss           | 6.94e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06e+03    |
# |    ep_rew_mean          | 7.55e+04    |
# | time/                   |             |
# |    fps                  | 859         |
# |    iterations           | 44          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.007578141 |
# |    clip_fraction        | 0.0165      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | -1.55e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53e+05    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00265    |
# |    value_loss           | 2.81e+05    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.06e+03  |
# |    ep_rew_mean          | 7.55e+04  |
# | time/                   |           |
# |    fps                  | 859       |
# |    iterations           | 45        |
# |    time_elapsed         | 107       |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.0012946 |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.87     |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.06e+05  |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.00153  |
# |    value_loss           | 3.87e+05  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.06e+03   |
# |    ep_rew_mean          | 7.53e+04   |
# | time/                   |            |
# |    fps                  | 859        |
# |    iterations           | 46         |
# |    time_elapsed         | 109        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01004676 |
# |    clip_fraction        | 0.026      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.89      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.82e+05   |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.00481   |
# |    value_loss           | 3.74e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+03    |
# |    ep_rew_mean          | 7.64e+04    |
# | time/                   |             |
# |    fps                  | 859         |
# |    iterations           | 47          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.008352486 |
# |    clip_fraction        | 0.011       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.06e+05    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00493    |
# |    value_loss           | 3.6e+05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.05e+03     |
# |    ep_rew_mean          | 7.53e+04     |
# | time/                   |              |
# |    fps                  | 858          |
# |    iterations           | 48           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0050399457 |
# |    clip_fraction        | 0.00562      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.67e+05     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0031      |
# |    value_loss           | 7.89e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | 7.53e+04    |
# | time/                   |             |
# |    fps                  | 858         |
# |    iterations           | 49          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.007061934 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27e+05    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00311    |
# |    value_loss           | 2.91e+05    |
# -----------------------------------------

# %%
def agent(obs):
    return model.predict(obs, deterministic=True)[0]

human_render_loop(agent, env, print_step=True)
# Out:
# initial state
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	info {'t': 0}
# step 1
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.03333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.03333333333333333}
# step 2
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.06666666666666667
# 	terminated False
# 	truncated False
# 	info {'t': 0.06666666666666667}
# step 3
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.1
# 	terminated False
# 	truncated False
# 	info {'t': 0.1}
# step 4
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.13333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.13333333333333333}
# step 5
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.16666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 0.16666666666666666}
# step 6
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.19999999999999998
# 	terminated False
# 	truncated False
# 	info {'t': 0.19999999999999998}
# step 7
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.2333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.2333333333333333}
# step 8
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.26666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 0.26666666666666666}
# step 9
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.3
# 	terminated False
# 	truncated False
# 	info {'t': 0.3}
# step 10
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.3333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.3333333333333333}
# step 11
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.36666666666666664
# 	terminated False
# 	truncated False
# 	info {'t': 0.36666666666666664}
# step 12
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.39999999999999997
# 	terminated False
# 	truncated False
# 	info {'t': 0.39999999999999997}
# step 13
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.4333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.4333333333333333}
# step 14
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.4666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 0.4666666666666666}
# step 15
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.49999999999999994
# 	terminated False
# 	truncated False
# 	info {'t': 0.49999999999999994}
# step 16
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.5333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.5333333333333333}
# step 17
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.5666666666666667
# 	terminated False
# 	truncated False
# 	info {'t': 0.5666666666666667}
# step 18
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.6
# 	terminated False
# 	truncated False
# 	info {'t': 0.6}
# step 19
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.6333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.6333333333333333}
# step 20
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.6666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 0.6666666666666666}
# step 21
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.7
# 	terminated False
# 	truncated False
# 	info {'t': 0.7}
# step 22
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.7333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.7333333333333333}
# step 23
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.7666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 0.7666666666666666}
# step 24
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.7999999999999999
# 	terminated False
# 	truncated False
# 	info {'t': 0.7999999999999999}
# step 25
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.8333333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 0.8333333333333333}
# step 26
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.8666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 0.8666666666666666}
# step 27
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.8999999999999999
# 	terminated False
# 	truncated False
# 	info {'t': 0.8999999999999999}
# step 28
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.9333333333333332
# 	terminated False
# 	truncated False
# 	info {'t': 0.9333333333333332}
# step 29
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.9666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 0.9666666666666666}
# step 30
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 0.9999999999999999
# 	terminated False
# 	truncated False
# 	info {'t': 0.9999999999999999}
# step 31
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 1.0333333333333332
# 	terminated False
# 	truncated False
# 	info {'t': 1.0333333333333332}
# step 32
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 1.0666666666666667
# 	terminated False
# 	truncated False
# 	info {'t': 1.0666666666666667}
# step 33
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 1.1
# 	terminated False
# 	truncated False
# 	info {'t': 1.1}
# step 34
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 931. 121. 131.]
# 	reward 1.1333333333333335
# 	terminated False
# 	truncated False
# 	info {'t': 1.1333333333333335}
# step 35
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         863.
#  182.          63.         922.66666667 121.         131.        ]
# 	reward 1.166666666666667
# 	terminated False
# 	truncated False
# 	info {'t': 1.166666666666667}
# step 36
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         863.
#  182.          63.         914.33333333 121.         131.        ]
# 	reward 1.2000000000000004
# 	terminated False
# 	truncated False
# 	info {'t': 1.2000000000000004}
# step 37
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 906. 121. 131.]
# 	reward 1.2333333333333338
# 	terminated False
# 	truncated False
# 	info {'t': 1.2333333333333338}
# step 38
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         863.
#  182.          63.         897.66666667 121.         131.        ]
# 	reward 1.2666666666666673
# 	terminated False
# 	truncated False
# 	info {'t': 1.2666666666666673}
# step 39
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         863.
#  182.          63.         889.33333333 121.         131.        ]
# 	reward 1.3000000000000007
# 	terminated False
# 	truncated False
# 	info {'t': 1.3000000000000007}
# step 40
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 881. 121. 131.]
# 	reward 1.3333333333333341
# 	terminated False
# 	truncated False
# 	info {'t': 1.3333333333333341}
# step 41
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         863.
#  182.          63.         872.66666667 121.         131.        ]
# 	reward 1.3666666666666676
# 	terminated False
# 	truncated False
# 	info {'t': 1.3666666666666676}
# step 42
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         863.
#  182.          63.         864.33333333 121.         131.        ]
# 	reward 1.400000000000001
# 	terminated False
# 	truncated False
# 	info {'t': 1.400000000000001}
# step 43
# 	action [0. 0. 0.]
# 	observation [300. 937.  99. 137. 863. 182.  63. 856. 121. 131.]
# 	reward 1.4333333333333345
# 	terminated False
# 	truncated False
# 	info {'t': 1.4333333333333345}
# step 44
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         863.
#  182.          63.         847.66666667 121.         131.        ]
# 	reward 1.466666666666668
# 	terminated False
# 	truncated False
# 	info {'t': 1.466666666666668}
# step 45
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         863.
#  182.          63.         839.33333333 121.         131.        ]
# 	reward 1.5000000000000013
# 	terminated False
# 	truncated False
# 	info {'t': 1.5000000000000013}
# step 46
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         854.66666667
#  182.          63.         831.         121.         131.        ]
# 	reward 1.5333333333333348
# 	terminated False
# 	truncated False
# 	info {'t': 1.5333333333333348}
# step 47
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         846.33333333
#  182.          63.         822.66666667 121.         131.        ]
# 	reward 1.5666666666666682
# 	terminated False
# 	truncated False
# 	info {'t': 1.5666666666666682}
# step 48
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         838.
#  182.          63.         814.33333333 121.         131.        ]
# 	reward 1.6000000000000016
# 	terminated False
# 	truncated False
# 	info {'t': 1.6000000000000016}
# step 49
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         829.66666667
#  182.          63.         806.         121.         131.        ]
# 	reward 1.633333333333335
# 	terminated False
# 	truncated False
# 	info {'t': 1.633333333333335}
# step 50
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         821.33333333
#  182.          63.         797.66666667 121.         131.        ]
# 	reward 1.6666666666666685
# 	terminated False
# 	truncated False
# 	info {'t': 1.6666666666666685}
# step 51
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         813.
#  182.          63.         789.33333333 121.         131.        ]
# 	reward 1.700000000000002
# 	terminated False
# 	truncated False
# 	info {'t': 1.700000000000002}
# step 52
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         804.66666667
#  182.          63.         781.         121.         131.        ]
# 	reward 1.7333333333333354
# 	terminated False
# 	truncated False
# 	info {'t': 1.7333333333333354}
# step 53
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         796.33333333
#  182.          63.         772.66666667 121.         131.        ]
# 	reward 1.7666666666666688
# 	terminated False
# 	truncated False
# 	info {'t': 1.7666666666666688}
# step 54
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         788.
#  182.          63.         764.33333333 121.         131.        ]
# 	reward 1.8000000000000023
# 	terminated False
# 	truncated False
# 	info {'t': 1.8000000000000023}
# step 55
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         779.66666667
#  182.          63.         756.         121.         131.        ]
# 	reward 1.8333333333333357
# 	terminated False
# 	truncated False
# 	info {'t': 1.8333333333333357}
# step 56
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         771.33333333
#  182.          63.         747.66666667 121.         131.        ]
# 	reward 1.8666666666666691
# 	terminated False
# 	truncated False
# 	info {'t': 1.8666666666666691}
# step 57
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         763.
#  182.          63.         739.33333333 121.         131.        ]
# 	reward 1.9000000000000026
# 	terminated False
# 	truncated False
# 	info {'t': 1.9000000000000026}
# step 58
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         754.66666667
#  182.          63.         731.         121.         131.        ]
# 	reward 1.933333333333336
# 	terminated False
# 	truncated False
# 	info {'t': 1.933333333333336}
# step 59
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         746.33333333
#  182.          63.         722.66666667 121.         131.        ]
# 	reward 1.9666666666666694
# 	terminated False
# 	truncated False
# 	info {'t': 1.9666666666666694}
# step 60
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         738.
#  182.          63.         714.33333333 121.         131.        ]
# 	reward 2.0000000000000027
# 	terminated False
# 	truncated False
# 	info {'t': 2.0000000000000027}
# step 61
# 	action [0. 0. 0.]
# 	observation [300.         937.          99.         137.         729.66666667
#  182.          63.         706.         121.         131.        ]
# 	reward 2.033333333333336
# 	terminated False
# 	truncated False
# 	info {'t': 2.033333333333336}
# step 62
# 	action [0. 0. 0.]
# 	observation [300.         928.66666667  99.         137.         721.33333333
#  182.          63.         697.66666667 121.         131.        ]
# 	reward 2.066666666666669
# 	terminated False
# 	truncated False
# 	info {'t': 2.066666666666669}
# step 63
# 	action [0. 0. 0.]
# 	observation [300.         920.33333333  99.         137.         713.
#  182.          63.         689.33333333 121.         131.        ]
# 	reward 2.1000000000000023
# 	terminated False
# 	truncated False
# 	info {'t': 2.1000000000000023}
# step 64
# 	action [0. 0. 0.]
# 	observation [300.         912.          99.         137.         704.66666667
#  182.          63.         681.         121.         131.        ]
# 	reward 2.1333333333333355
# 	terminated False
# 	truncated False
# 	info {'t': 2.1333333333333355}
# step 65
# 	action [0. 0. 0.]
# 	observation [300.         903.66666667  99.         137.         696.33333333
#  182.          63.         672.66666667 121.         131.        ]
# 	reward 2.1666666666666687
# 	terminated False
# 	truncated False
# 	info {'t': 2.1666666666666687}
# step 66
# 	action [0. 0. 0.]
# 	observation [300.         895.33333333  99.         137.         688.
#  182.          63.         664.33333333 121.         131.        ]
# 	reward 2.200000000000002
# 	terminated False
# 	truncated False
# 	info {'t': 2.200000000000002}
# step 67
# 	action [0. 0. 0.]
# 	observation [300.         887.          99.         137.         679.66666667
#  182.          63.         656.         121.         131.        ]
# 	reward 2.233333333333335
# 	terminated False
# 	truncated False
# 	info {'t': 2.233333333333335}
# step 68
# 	action [0. 0. 0.]
# 	observation [300.         878.66666667  99.         137.         671.33333333
#  182.          63.         647.66666667 121.         131.        ]
# 	reward 2.2666666666666684
# 	terminated False
# 	truncated False
# 	info {'t': 2.2666666666666684}
# step 69
# 	action [0. 0. 0.]
# 	observation [300.         870.33333333  99.         137.         663.
#  182.          63.         639.33333333 121.         131.        ]
# 	reward 2.3000000000000016
# 	terminated False
# 	truncated False
# 	info {'t': 2.3000000000000016}
# step 70
# 	action [0. 0. 0.]
# 	observation [300.         862.          99.         137.         654.66666667
#  182.          63.         631.         121.         131.        ]
# 	reward 2.333333333333335
# 	terminated False
# 	truncated False
# 	info {'t': 2.333333333333335}
# step 71
# 	action [0. 0. 0.]
# 	observation [300.         853.66666667  99.         137.         646.33333333
#  182.          63.         622.66666667 121.         131.        ]
# 	reward 2.366666666666668
# 	terminated False
# 	truncated False
# 	info {'t': 2.366666666666668}
# step 72
# 	action [0. 0. 0.]
# 	observation [300.         845.33333333  99.         137.         638.
#  182.          63.         614.33333333 121.         131.        ]
# 	reward 2.4000000000000012
# 	terminated False
# 	truncated False
# 	info {'t': 2.4000000000000012}
# step 73
# 	action [0. 0. 0.]
# 	observation [300.         837.          99.         137.         629.66666667
#  182.          63.         606.         121.         131.        ]
# 	reward 2.4333333333333345
# 	terminated False
# 	truncated False
# 	info {'t': 2.4333333333333345}
# step 74
# 	action [0. 0. 0.]
# 	observation [300.         828.66666667  99.         137.         621.33333333
#  182.          63.         597.66666667 121.         131.        ]
# 	reward 2.4666666666666677
# 	terminated False
# 	truncated False
# 	info {'t': 2.4666666666666677}
# step 75
# 	action [0. 0. 0.]
# 	observation [300.         820.33333333  99.         137.         613.
#  182.          63.         589.33333333 121.         131.        ]
# 	reward 2.500000000000001
# 	terminated False
# 	truncated False
# 	info {'t': 2.500000000000001}
# step 76
# 	action [0. 0. 0.]
# 	observation [300.         812.          99.         137.         604.66666667
#  182.          63.         581.         121.         131.        ]
# 	reward 2.533333333333334
# 	terminated False
# 	truncated False
# 	info {'t': 2.533333333333334}
# step 77
# 	action [0. 0. 0.]
# 	observation [300.         803.66666667  99.         137.         596.33333333
#  182.          63.         572.66666667 121.         131.        ]
# 	reward 2.5666666666666673
# 	terminated False
# 	truncated False
# 	info {'t': 2.5666666666666673}
# step 78
# 	action [0. 0. 0.]
# 	observation [300.         795.33333333  99.         137.         588.
#  182.          63.         564.33333333 121.         131.        ]
# 	reward 2.6000000000000005
# 	terminated False
# 	truncated False
# 	info {'t': 2.6000000000000005}
# step 79
# 	action [0. 0. 0.]
# 	observation [300.         787.          99.         137.         579.66666667
#  182.          63.         556.         121.         131.        ]
# 	reward 2.6333333333333337
# 	terminated False
# 	truncated False
# 	info {'t': 2.6333333333333337}
# step 80
# 	action [0. 0. 0.]
# 	observation [300.         778.66666667  99.         137.         571.33333333
#  182.          63.         547.66666667 121.         131.        ]
# 	reward 2.666666666666667
# 	terminated False
# 	truncated False
# 	info {'t': 2.666666666666667}
# step 81
# 	action [0. 0. 0.]
# 	observation [300.         770.33333333  99.         137.         563.
#  182.          63.         539.33333333 121.         131.        ]
# 	reward 2.7
# 	terminated False
# 	truncated False
# 	info {'t': 2.7}
# step 82
# 	action [0. 0. 0.]
# 	observation [300.         762.          99.         137.         554.66666667
#  182.          63.         531.         121.         131.        ]
# 	reward 2.7333333333333334
# 	terminated False
# 	truncated False
# 	info {'t': 2.7333333333333334}
# step 83
# 	action [0. 0. 0.]
# 	observation [300.         753.66666667  99.         137.         546.33333333
#  182.          63.         522.66666667 121.         131.        ]
# 	reward 2.7666666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 2.7666666666666666}
# step 84
# 	action [0. 0. 0.]
# 	observation [300.         745.33333333  99.         137.         538.
#  182.          63.         514.33333333 121.         131.        ]
# 	reward 2.8
# 	terminated False
# 	truncated False
# 	info {'t': 2.8}
# step 85
# 	action [0. 0. 0.]
# 	observation [300.         737.          99.         137.         529.66666667
#  182.          63.         506.         121.         131.        ]
# 	reward 2.833333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 2.833333333333333}
# step 86
# 	action [0. 0. 0.]
# 	observation [300.         728.66666667  99.         137.         521.33333333
#  182.          63.         497.66666667 121.         131.        ]
# 	reward 2.8666666666666663
# 	terminated False
# 	truncated False
# 	info {'t': 2.8666666666666663}
# step 87
# 	action [0. 0. 0.]
# 	observation [300.         720.33333333  99.         137.         513.
#  182.          63.         489.33333333 121.         131.        ]
# 	reward 2.8999999999999995
# 	terminated False
# 	truncated False
# 	info {'t': 2.8999999999999995}
# step 88
# 	action [0. 0. 0.]
# 	observation [300.         712.          99.         137.         504.66666667
#  182.          63.         481.         121.         131.        ]
# 	reward 2.9333333333333327
# 	terminated False
# 	truncated False
# 	info {'t': 2.9333333333333327}
# step 89
# 	action [0. 0. 0.]
# 	observation [300.         703.66666667  99.         137.         496.33333333
#  182.          63.         472.66666667 121.         131.        ]
# 	reward 2.966666666666666
# 	terminated False
# 	truncated False
# 	info {'t': 2.966666666666666}
# step 90
# 	action [0. 0. 0.]
# 	observation [300.         695.33333333  99.         137.         488.
#  182.          63.         464.33333333 121.         131.        ]
# 	reward 2.999999999999999
# 	terminated False
# 	truncated False
# 	info {'t': 2.999999999999999}
# step 91
# 	action [0. 0. 0.]
# 	observation [300.         687.          99.         137.         479.66666667
#  182.          63.         456.         121.         131.        ]
# 	reward 3.0333333333333323
# 	terminated False
# 	truncated False
# 	info {'t': 3.0333333333333323}
# step 92
# 	action [0. 0. 0.]
# 	observation [300.         678.66666667  99.         137.         471.33333333
#  182.          63.         447.66666667 121.         131.        ]
# 	reward 3.0666666666666655
# 	terminated False
# 	truncated False
# 	info {'t': 3.0666666666666655}
# step 93
# 	action [0. 0. 0.]
# 	observation [300.         670.33333333  99.         137.         463.
#  182.          63.         439.33333333 121.         131.        ]
# 	reward 3.0999999999999988
# 	terminated False
# 	truncated False
# 	info {'t': 3.0999999999999988}
# step 94
# 	action [0. 0. 0.]
# 	observation [300.         662.          99.         137.         454.66666667
#  182.          63.         431.         121.         131.        ]
# 	reward 3.133333333333332
# 	terminated False
# 	truncated False
# 	info {'t': 3.133333333333332}
# step 95
# 	action [0. 0. 0.]
# 	observation [300.         653.66666667  99.         137.         446.33333333
#  182.          63.         422.66666667 121.         131.        ]
# 	reward 3.166666666666665
# 	terminated False
# 	truncated False
# 	info {'t': 3.166666666666665}
# step 96
# 	action [0. 0. 0.]
# 	observation [300.         645.33333333  99.         137.         438.
#  182.          63.         414.33333333 121.         131.        ]
# 	reward 3.1999999999999984
# 	terminated False
# 	truncated False
# 	info {'t': 3.1999999999999984}
# step 97
# 	action [0. 0. 0.]
# 	observation [300.         637.          99.         137.         429.66666667
#  182.          63.         406.         121.         131.        ]
# 	reward 3.2333333333333316
# 	terminated False
# 	truncated False
# 	info {'t': 3.2333333333333316}
# step 98
# 	action [0. 0. 0.]
# 	observation [300.         628.66666667  99.         137.         421.33333333
#  182.          63.         397.66666667 121.         131.        ]
# 	reward 3.266666666666665
# 	terminated False
# 	truncated False
# 	info {'t': 3.266666666666665}
# step 99
# 	action [0. 0. 0.]
# 	observation [300.         620.33333333  99.         137.         413.
#  182.          63.         389.33333333 121.         131.        ]
# 	reward 3.299999999999998
# 	terminated False
# 	truncated False
# 	info {'t': 3.299999999999998}
# step 100
# 	action [0. 0. 0.]
# 	observation [300.         612.          99.         137.         404.66666667
#  182.          63.         381.         121.         131.        ]
# 	reward 3.3333333333333313
# 	terminated False
# 	truncated False
# 	info {'t': 3.3333333333333313}
# step 101
# 	action [0. 0. 0.]
# 	observation [300.         603.66666667  99.         137.         396.33333333
#  182.          63.         372.66666667 121.         131.        ]
# 	reward 3.3666666666666645
# 	terminated False
# 	truncated False
# 	info {'t': 3.3666666666666645}
# step 102
# 	action [0. 0. 0.]
# 	observation [300.         595.33333333  99.         137.         388.
#  182.          63.         364.33333333 121.         131.        ]
# 	reward 3.3999999999999977
# 	terminated False
# 	truncated False
# 	info {'t': 3.3999999999999977}
# step 103
# 	action [0. 0. 0.]
# 	observation [300.         587.          99.         137.         379.66666667
#  182.          63.         356.         121.         131.        ]
# 	reward 3.433333333333331
# 	terminated False
# 	truncated False
# 	info {'t': 3.433333333333331}
# step 104
# 	action [0. 0. 0.]
# 	observation [300.         578.66666667  99.         137.         371.33333333
#  182.          63.         347.66666667 121.         131.        ]
# 	reward 3.466666666666664
# 	terminated False
# 	truncated False
# 	info {'t': 3.466666666666664}
# step 105
# 	action [1. 0. 0.]
# 	observation [291.66666667 570.33333333  99.         137.         363.
#  182.          63.         339.33333333 121.         131.        ]
# 	reward 3.4999999999999973
# 	terminated False
# 	truncated False
# 	info {'t': 3.4999999999999973}
# step 106
# 	action [1. 0. 0.]
# 	observation [283.33333333 562.          99.         137.         354.66666667
#  182.          63.         331.         121.         131.        ]
# 	reward 3.5333333333333306
# 	terminated False
# 	truncated False
# 	info {'t': 3.5333333333333306}
# step 107
# 	action [1. 0. 0.]
# 	observation [275.         553.66666667  99.         137.         346.33333333
#  182.          63.         322.66666667 121.         131.        ]
# 	reward 3.5666666666666638
# 	terminated False
# 	truncated False
# 	info {'t': 3.5666666666666638}
# step 108
# 	action [1. 0. 0.]
# 	observation [266.66666667 545.33333333  99.         137.         338.
#  182.          63.         314.33333333 121.         131.        ]
# 	reward 3.599999999999997
# 	terminated False
# 	truncated False
# 	info {'t': 3.599999999999997}
# step 109
# 	action [1. 0. 0.]
# 	observation [258.33333333 537.          99.         137.         329.66666667
#  182.          63.         306.         121.         131.        ]
# 	reward 3.63333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 3.63333333333333}
# step 110
# 	action [1. 0. 0.]
# 	observation [250.         528.66666667  99.         137.         321.33333333
#  182.          63.         297.66666667 121.         131.        ]
# 	reward 3.6666666666666634
# 	terminated False
# 	truncated False
# 	info {'t': 3.6666666666666634}
# step 111
# 	action [1. 0. 0.]
# 	observation [241.66666667 520.33333333  99.         137.         313.
#  182.          63.         289.33333333 121.         131.        ]
# 	reward 3.6999999999999966
# 	terminated False
# 	truncated False
# 	info {'t': 3.6999999999999966}
# step 112
# 	action [1. 0. 0.]
# 	observation [233.33333333 512.          99.         137.         304.66666667
#  182.          63.         281.         121.         131.        ]
# 	reward 3.73333333333333
# 	terminated False
# 	truncated False
# 	info {'t': 3.73333333333333}
# step 113
# 	action [1. 0. 0.]
# 	observation [225.         503.66666667  99.         137.         296.33333333
#  182.          63.         272.66666667 121.         131.        ]
# 	reward 3.766666666666663
# 	terminated False
# 	truncated False
# 	info {'t': 3.766666666666663}
# step 114
# 	action [1. 0. 0.]
# 	observation [216.66666667 495.33333333  99.         137.         288.
#  182.          63.         264.33333333 121.         131.        ]
# 	reward 3.7999999999999963
# 	terminated False
# 	truncated False
# 	info {'t': 3.7999999999999963}
# step 115
# 	action [1. 0. 0.]
# 	observation [208.33333333 487.          99.         137.         279.66666667
#  182.          63.         256.         121.         131.        ]
# 	reward 3.8333333333333295
# 	terminated False
# 	truncated False
# 	info {'t': 3.8333333333333295}
# step 116
# 	action [1. 0. 0.]
# 	observation [200.         478.66666667  99.         137.         271.33333333
#  182.          63.         247.66666667 121.         131.        ]
# 	reward 3.8666666666666627
# 	terminated False
# 	truncated False
# 	info {'t': 3.8666666666666627}
# step 117
# 	action [1. 0. 0.]
# 	observation [191.66666667 470.33333333  99.         137.         263.
#  182.          63.         239.33333333 121.         131.        ]
# 	reward 3.899999999999996
# 	terminated False
# 	truncated False
# 	info {'t': 3.899999999999996}
# step 118
# 	action [1. 0. 0.]
# 	observation [183.33333333 462.          99.         137.         254.66666667
#  182.          63.         231.         121.         131.        ]
# 	reward 3.933333333333329
# 	terminated False
# 	truncated False
# 	info {'t': 3.933333333333329}
# step 119
# 	action [1. 0. 0.]
# 	observation [175.         453.66666667  99.         137.         246.33333333
#  182.          63.         222.66666667 121.         131.        ]
# 	reward 3.9666666666666623
# 	terminated False
# 	truncated False
# 	info {'t': 3.9666666666666623}
# step 120
# 	action [1. 0. 0.]
# 	observation [166.66666667 445.33333333  99.         137.         238.
#  182.          63.         214.33333333 121.         131.        ]
# 	reward 3.9999999999999956
# 	terminated True
# 	truncated False
# 	info {'t': 3.9999999999999956}
# Total reward 241.99999999999997
