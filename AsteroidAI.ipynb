# %%
import gymnasium as gym
from gymnasium.spaces import Discrete, Tuple, Box
import numpy as np
import pygame
import random
import math

# %%
def human_render_loop(agent, env, transpose=False, print_step=False):
    obs, info = env.reset()

    clock = pygame.time.Clock()
    fps = env.metadata["render_fps"]

    pygame.display.init()
    size = env.render().shape[:2]
    if transpose:
        size = size[::-1]

    display = pygame.display.set_mode(size)

    term = trunc = quit = False
    step = 0
    total_reward = 0

    if print_step:
        print("initial state")
        print("\tobservation", obs)
        print("\tinfo", info)

    while not (term or trunc or quit):
        quit = pygame.key.get_pressed()[pygame.K_q]

        action = agent(obs)
        obs, reward, term, trunc, info = env.step(action)

        pygame.event.pump()

        step += 1
        total_reward += reward

        if print_step:
            print("step", step)
            print("\taction", action)
            print("\tobservation", obs)
            print("\treward", reward)
            print("\tterminated", term)
            print("\ttruncated", trunc)
            print("\tinfo", info)

        frame = env.render()
        if transpose:
            frame = frame.transpose((1, 0, 2))

        pygame.surfarray.blit_array(display, frame)
        pygame.display.flip()
        clock.tick(fps)

    if print_step:
        print("Total reward", total_reward)

    pygame.display.quit()

# %% [markdown]
# Game

# %%
HEIGHT = 600
WIDTH = 800

ASTEROID_NBR = 10
ASTEROID_SPEED = 5
ASTEROID_MIN_RADIUS = 50
ASTEROID_MAX_RADIUS = 150
SHIP_SPEED = 5
MISSILE_SPEED = 10

DT_MILLIS = 50

# Couleurs
WHITE = (150, 0, 0)
BLACK = (0, 0, 0)
YELLOW = (255, 255, 0)

# Chargement des images
ship_image = pygame.image.load("ship.png")
asteroid_base_image = pygame.image.load("asteroid.png")

ship_image.set_colorkey((0, 0, 0)) # Set black as the transparent color
asteroid_base_image.set_colorkey((0, 0, 0)) # Set black as the transparent color

# Rotation et redimensionnement de la fusée
ship_image = pygame.transform.rotate(ship_image, -90)  # Rotate 90 degrees to the right
ship_image = pygame.transform.scale(ship_image, (ship_image.get_width() // 2.5, ship_image.get_height() // 2.5))

# Classe pour la fusée
class Ship:
    def __init__(self):
        self.x = 50
        self.y = HEIGHT // 2
        self.speed = SHIP_SPEED
        self.vy = 0
        self.width = ship_image.get_width()
        self.height = ship_image.get_height()

    def update(self, dt):
        self.y += self.vy * dt * DT_MILLIS 
        if self.y < 0:
            self.y = 0
        elif self.y > HEIGHT - self.height:
            self.y = HEIGHT - self.height

    def draw(self, screen):
        screen.blit(ship_image, (self.x, self.y))

    def get_collision_boxes(self):
        # Divides the ship into 3 smaller rectangles for better collision detection
        box_width = self.width // 3
        boxes = [
            pygame.Rect(self.x, self.y, box_width, self.height),  # Left box
            pygame.Rect(self.x + box_width, self.y + self.height / 2 / 2, box_width, self.height / 2),  # Middle box
            pygame.Rect(self.x + 2 * box_width, self.y + self.height / 2.65, box_width * 0.7, self.height / 4),  # Right box
            pygame.Rect(self.x + 2.7 * box_width, self.y + self.height / 2.265, box_width * 0.3, self.height / 8)  # Right box
        ]
        return boxes

class Missile:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.vx = MISSILE_SPEED

    def update(self, dt):
        self.x += self.vx * dt * DT_MILLIS 

    def draw(self, screen):
        pygame.draw.rect(screen, YELLOW, (self.x, self.y - 2, 10, 4))

class Asteroid:
    def __init__(self):
        self.vx = ASTEROID_SPEED
        self.reset_position()
        self.spawn_delay = random.uniform(1, 3)
        self.spawn_time = pygame.time.get_ticks()  # Record the current time

    def reset_position(self):
        self.radius = random.randint(ASTEROID_MIN_RADIUS, ASTEROID_MAX_RADIUS)
        self.x = WIDTH + self.radius
        self.y = random.randint(0, HEIGHT)
        

    def update(self, dt):
        if pygame.time.get_ticks() - self.spawn_time > self.spawn_delay * 1000:
            self.x -= self.vx * dt * DT_MILLIS 
            if self.x < -self.radius * 2:
                self.reset_position()

    def draw(self, screen):
        image = pygame.transform.scale(asteroid_base_image, (self.radius * 2, self.radius * 2))
        screen.blit(image, (int(self.x - self.radius), int(self.y - self.radius)))

    def shrink(self):
        self.radius = int(self.radius * 0.75)
        if self.radius < 20:
            self.reset_position()

    def get_info(self):
        return self.x, self.y, self.radius

def check_ship_collision(ship, asteroids):
    collision_boxes = ship.get_collision_boxes()
    for asteroid in asteroids:
        for box in collision_boxes:
            if Collision_cicle_rect((asteroid.x, asteroid.y), asteroid.radius, (box.centerx, box.centery), box.width, box.height):
                return True
    return False

def Collision_cicle_rect(circle_center, circle_radius, rect_center, rect_width, rect_height):
    c_x, c_y = circle_center
    r_x, r_y = rect_center
    r_width, r_height = rect_width, rect_height

    # Calculate rectangle bounds
    r_min_x = r_x - r_width / 2
    r_max_x = r_x + r_width / 2
    r_min_y = r_y - r_height / 2
    r_max_y = r_y + r_height / 2

    # Find the closest point on the rectangle to the circle's center
    closest_x = max(r_min_x, min(c_x, r_max_x))
    closest_y = max(r_min_y, min(c_y, r_max_y))

    # Calculate distance from the circle's center to the closest point
    distance_squared = (c_x - closest_x) ** 2 + (c_y - closest_y) ** 2

    # Check for collision
    return distance_squared <= circle_radius ** 2

def check_missile_collision(missiles, asteroids):
    for missile in missiles[:]:
        for asteroid in asteroids:
            distance = math.hypot(missile.x - asteroid.x, missile.y - asteroid.y)
            if distance < asteroid.radius:
                asteroid.shrink()
                missiles.remove(missile)
                break

# %% [markdown]
# Environnement

# %%
class AsteroidEnv(gym.Env):
    metadata = {"render_modes": ["rgb_array"], "render_fps": 30}

    def __init__(self, worldSize=(WIDTH, HEIGHT), asteroidNbr = ASTEROID_NBR,  render_mode=None):
        super().__init__()

        self.worldSize = worldSize
        self.width = worldSize[0]
        self.height = worldSize[1]
        self.asteroidNbr = asteroidNbr
        self.dt = 1 / self.metadata["render_fps"]

        self.t = 0
        self.x = np.zeros(1 + 3*self.asteroidNbr)  # y + (x,y,r)*asteroidNbr   (xShip vyShip et vxAsteroid = constantes)
        self.u = np.zeros(3)  # up, down, shoot

        self.ship = Ship()
        self.asteroids = [Asteroid() for _ in range(asteroidNbr)]
        self.missiles = []

        self.observation_space = Box(
            low= np.zeros(1 + 3*self.asteroidNbr),
            high=np.array([self.height - self.ship.height] + [self.width + ASTEROID_MAX_RADIUS*2, self.height, ASTEROID_MAX_RADIUS] * self.asteroidNbr),
            shape=(1 + 3*self.asteroidNbr,),
            dtype=np.float32
        )
        self.action_space = Tuple((Discrete(2), Discrete(2), Discrete(2))) # up, down, shoot

        self.render_mode = render_mode

    def _dynamic_step(self, action):
        self.t += self.dt
        self.u = action

        # Move ship
        if self.u[0]:
            self.ship.vy = -self.ship.speed
        elif self.u[1]:
            self.ship.vy = self.ship.speed
        else:
            self.ship.vy = 0

        self.ship.update(self.dt)
        self.x[0] = self.ship.y

        # Move asteroids
        for asteroid in self.asteroids:
            asteroid.update(self.dt)
        self.x[1:] = [coord for a in self.asteroids for coord in a.get_info()]

        
        # Move missles
        if (self.u[2]):
            self.missiles.append(Missile(self.ship.x + self.ship.width, self.ship.y + self.ship.height // 2))

        for missile in self.missiles:
            missile.update(self.dt)
            if missile.x > WIDTH:
                self.missiles.remove(missile)

        # Check for collisions between asteroids and missles 
        check_missile_collision(self.missiles, self.asteroids)
         

    def _g(self):
        # u = self.u
        # delta_x = next_obs = self._get_observation()

        # # à compléter - la fonction de coût
        # Q = np.array([1.0, 1.0, 0.01, 0.01])
        # R = np.array([0.01, 0.01])

        # cout = (Q * delta_x**2).sum() + (R * u**2).sum() * self.dt

        # cout += 1000 * (not self.observation_space.contains(next_obs))

        # Reward survival
        return 1

    def _get_observation(self):
        return self.x

    def _should_truncate(self):
        return False #not self.observation_space.contains(self._get_observation())

    def _should_terminate(self):
        return check_ship_collision(self.ship, self.asteroids)
    
    def _get_info(self):
        return {
            "t": self.t
        }

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        self.t = 0

        observation = self.observation_space.sample()

        self.ship = Ship()
        self.asteroids = [Asteroid() for _ in range(self.asteroidNbr)]
        self.missiles = []

        self.x[0] = self.ship.y
        self.x[1:] = [coord for a in self.asteroids for coord in a.get_info()]

        observation = self._get_observation()

        self.u = np.zeros(3)

        info = self._get_info()

        return observation, info

    def step(self, action):
        # à compléter - les étape d'un step
        self._dynamic_step(action)
        observation = self._get_observation()
        reward = self._g()
        terminate = self._should_terminate()
        truncate = self._should_truncate()
        info = self._get_info()

        return observation, reward, terminate, truncate, info

    def render(self):
        if self.render_mode == "rgb_array":

            size = pygame.Vector2(self.worldSize)
            surface = pygame.Surface(size, flags=pygame.SRCALPHA)

            # Drawing the ship
            self.ship.draw(surface)

            # Drawing the asteroids
            for asteroid in self.asteroids:
                asteroid.draw(surface)

            # Drawing the missiles
            for missile in self.missiles:
                missile.draw(surface)

            return pygame.surfarray.pixels3d(surface)

# %%
gym.register(id="AsteroidEnv-v0", entry_point="__main__:AsteroidEnv")

env = gym.make("AsteroidEnv-v0", render_mode="rgb_array", max_episode_steps=100000)

# %%
def human_agent(_obs):
    keys = pygame.key.get_pressed()
    pygame.event.pump()

    if keys[pygame.K_UP] :
        up =1
    else:
        up = 0

    if keys[pygame.K_DOWN] :
        down =1
    else:
        down = 0

    if keys[pygame.K_SPACE] :
        space =1
    else:
        space = 0

    action = np.array([up,down,space])

    return action

# %%
human_render_loop(human_agent, env, print_step=True)
# Out:
# initial state
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	info {'t': 0}
# step 1
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.03333333333333333}
# step 2
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.06666666666666667}
# step 3
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.1}
# step 4
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.13333333333333333}
# step 5
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.16666666666666666}
# step 6
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.19999999999999998}
# step 7
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.2333333333333333}
# step 8
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.26666666666666666}
# step 9
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.3}
# step 10
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.3333333333333333}
# step 11
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.36666666666666664}
# step 12
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.39999999999999997}
# step 13
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.4333333333333333}
# step 14
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.4666666666666666}
# step 15
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.49999999999999994}
# step 16
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5333333333333333}
# step 17
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.5666666666666667}
# step 18
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6}
# step 19
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6333333333333333}
# step 20
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.6666666666666666}
# step 21
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7}
# step 22
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7333333333333333}
# step 23
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7666666666666666}
# step 24
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.7999999999999999}
# step 25
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8333333333333333}
# step 26
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8666666666666666}
# step 27
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.8999999999999999}
# step 28
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.9333333333333332}
# step 29
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.9666666666666666}
# step 30
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 0.9999999999999999}
# step 31
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 929.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.0333333333333332}
# step 32
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         868.
#   30.          68.         920.66666667  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         927.
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.0666666666666667}
# step 33
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         868.
#   30.          68.         912.33333333  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         927.
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.1}
# step 34
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 904.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.1333333333333335}
# step 35
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         868.
#   30.          68.         895.66666667  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         927.
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.166666666666667}
# step 36
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         868.
#   30.          68.         887.33333333  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         927.
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.2000000000000004}
# step 37
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 879.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.2333333333333338}
# step 38
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         868.
#   30.          68.         870.66666667  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         927.
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.2666666666666673}
# step 39
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         868.
#   30.          68.         862.33333333  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         927.
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.3000000000000007}
# step 40
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 868.  30.  68. 854.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.3333333333333341}
# step 41
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         859.66666667
#   30.          68.         845.66666667  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         927.
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.3666666666666676}
# step 42
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         851.33333333
#   30.          68.         837.33333333  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         927.
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.400000000000001}
# step 43
# 	action [0 0 0]
# 	observation [300. 870. 352.  70. 843.  30.  68. 829.  61. 129. 920. 128. 120. 866.
#  207.  66. 938. 427. 138. 927. 487. 127. 864. 211.  64. 893. 586.  93.
#  901. 342. 101.]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.4333333333333345}
# step 44
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         834.66666667
#   30.          68.         820.66666667  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         927.
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.466666666666668}
# step 45
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         826.33333333
#   30.          68.         812.33333333  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         918.66666667
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.5000000000000013}
# step 46
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         818.
#   30.          68.         804.          61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         910.33333333
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.5333333333333348}
# step 47
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         809.66666667
#   30.          68.         795.66666667  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         902.
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.5666666666666682}
# step 48
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         801.33333333
#   30.          68.         787.33333333  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         893.66666667
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.6000000000000016}
# step 49
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         793.
#   30.          68.         779.          61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         885.33333333
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.633333333333335}
# step 50
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         784.66666667
#   30.          68.         770.66666667  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         877.
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.6666666666666685}
# step 51
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         776.33333333
#   30.          68.         762.33333333  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         868.66666667
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.700000000000002}
# step 52
# 	action [0 0 0]
# 	observation [300.         870.         352.          70.         768.
#   30.          68.         754.          61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         860.33333333
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.7333333333333354}
# step 53
# 	action [0 0 0]
# 	observation [300.         861.66666667 352.          70.         759.66666667
#   30.          68.         745.66666667  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         852.
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.7666666666666688}
# step 54
# 	action [0 0 0]
# 	observation [300.         853.33333333 352.          70.         751.33333333
#   30.          68.         737.33333333  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         843.66666667
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.8000000000000023}
# step 55
# 	action [0 0 0]
# 	observation [300.         845.         352.          70.         743.
#   30.          68.         729.          61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         835.33333333
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.8333333333333357}
# step 56
# 	action [0 0 0]
# 	observation [300.         836.66666667 352.          70.         734.66666667
#   30.          68.         720.66666667  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         827.
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.8666666666666691}
# step 57
# 	action [0 0 0]
# 	observation [300.         828.33333333 352.          70.         726.33333333
#   30.          68.         712.33333333  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         818.66666667
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.9000000000000026}
# step 58
# 	action [0 0 0]
# 	observation [300.         820.         352.          70.         718.
#   30.          68.         704.          61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         810.33333333
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.933333333333336}
# step 59
# 	action [0 0 0]
# 	observation [300.         811.66666667 352.          70.         709.66666667
#   30.          68.         695.66666667  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         802.
#  487.         127.         864.         211.          64.
#  893.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 1.9666666666666694}
# step 60
# 	action [0 0 0]
# 	observation [300.         803.33333333 352.          70.         701.33333333
#   30.          68.         687.33333333  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         793.66666667
#  487.         127.         864.         211.          64.
#  884.66666667 586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.0000000000000027}
# step 61
# 	action [0 0 0]
# 	observation [300.         795.         352.          70.         693.
#   30.          68.         679.          61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         785.33333333
#  487.         127.         864.         211.          64.
#  876.33333333 586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.033333333333336}
# step 62
# 	action [0 0 0]
# 	observation [300.         786.66666667 352.          70.         684.66666667
#   30.          68.         670.66666667  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         777.
#  487.         127.         864.         211.          64.
#  868.         586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.066666666666669}
# step 63
# 	action [0 0 0]
# 	observation [300.         778.33333333 352.          70.         676.33333333
#   30.          68.         662.33333333  61.         129.
#  920.         128.         120.         866.         207.
#   66.         938.         427.         138.         768.66666667
#  487.         127.         864.         211.          64.
#  859.66666667 586.          93.         901.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.1000000000000023}
# step 64
# 	action [0 0 0]
# 	observation [300.         770.         352.          70.         668.
#   30.          68.         654.          61.         129.
#  920.         128.         120.         866.         207.
#   66.         929.66666667 427.         138.         760.33333333
#  487.         127.         864.         211.          64.
#  851.33333333 586.          93.         892.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.1333333333333355}
# step 65
# 	action [0 0 0]
# 	observation [300.         761.66666667 352.          70.         659.66666667
#   30.          68.         645.66666667  61.         129.
#  920.         128.         120.         866.         207.
#   66.         921.33333333 427.         138.         752.
#  487.         127.         855.66666667 211.          64.
#  843.         586.          93.         884.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.1666666666666687}
# step 66
# 	action [0 0 0]
# 	observation [300.         753.33333333 352.          70.         651.33333333
#   30.          68.         637.33333333  61.         129.
#  920.         128.         120.         866.         207.
#   66.         913.         427.         138.         743.66666667
#  487.         127.         847.33333333 211.          64.
#  834.66666667 586.          93.         876.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.200000000000002}
# step 67
# 	action [0 0 0]
# 	observation [300.         745.         352.          70.         643.
#   30.          68.         629.          61.         129.
#  920.         128.         120.         866.         207.
#   66.         904.66666667 427.         138.         735.33333333
#  487.         127.         839.         211.          64.
#  826.33333333 586.          93.         867.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.233333333333335}
# step 68
# 	action [0 0 0]
# 	observation [300.         736.66666667 352.          70.         634.66666667
#   30.          68.         620.66666667  61.         129.
#  920.         128.         120.         866.         207.
#   66.         896.33333333 427.         138.         727.
#  487.         127.         830.66666667 211.          64.
#  818.         586.          93.         859.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.2666666666666684}
# step 69
# 	action [0 0 0]
# 	observation [300.         728.33333333 352.          70.         626.33333333
#   30.          68.         612.33333333  61.         129.
#  920.         128.         120.         866.         207.
#   66.         888.         427.         138.         718.66666667
#  487.         127.         822.33333333 211.          64.
#  809.66666667 586.          93.         851.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.3000000000000016}
# step 70
# 	action [0 0 0]
# 	observation [300.         720.         352.          70.         618.
#   30.          68.         604.          61.         129.
#  920.         128.         120.         866.         207.
#   66.         879.66666667 427.         138.         710.33333333
#  487.         127.         814.         211.          64.
#  801.33333333 586.          93.         842.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.333333333333335}
# step 71
# 	action [0 0 0]
# 	observation [300.         711.66666667 352.          70.         609.66666667
#   30.          68.         595.66666667  61.         129.
#  920.         128.         120.         857.66666667 207.
#   66.         871.33333333 427.         138.         702.
#  487.         127.         805.66666667 211.          64.
#  793.         586.          93.         834.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.366666666666668}
# step 72
# 	action [0 0 0]
# 	observation [300.         703.33333333 352.          70.         601.33333333
#   30.          68.         587.33333333  61.         129.
#  920.         128.         120.         849.33333333 207.
#   66.         863.         427.         138.         693.66666667
#  487.         127.         797.33333333 211.          64.
#  784.66666667 586.          93.         826.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.4000000000000012}
# step 73
# 	action [1 0 0]
# 	observation [291.66666667 695.         352.          70.         593.
#   30.          68.         579.          61.         129.
#  920.         128.         120.         841.         207.
#   66.         854.66666667 427.         138.         685.33333333
#  487.         127.         789.         211.          64.
#  776.33333333 586.          93.         817.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.4333333333333345}
# step 74
# 	action [1 0 0]
# 	observation [283.33333333 686.66666667 352.          70.         584.66666667
#   30.          68.         570.66666667  61.         129.
#  920.         128.         120.         832.66666667 207.
#   66.         846.33333333 427.         138.         677.
#  487.         127.         780.66666667 211.          64.
#  768.         586.          93.         809.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.4666666666666677}
# step 75
# 	action [1 0 0]
# 	observation [275.         678.33333333 352.          70.         576.33333333
#   30.          68.         562.33333333  61.         129.
#  920.         128.         120.         824.33333333 207.
#   66.         838.         427.         138.         668.66666667
#  487.         127.         772.33333333 211.          64.
#  759.66666667 586.          93.         801.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.500000000000001}
# step 76
# 	action [1 0 0]
# 	observation [266.66666667 670.         352.          70.         568.
#   30.          68.         554.          61.         129.
#  920.         128.         120.         816.         207.
#   66.         829.66666667 427.         138.         660.33333333
#  487.         127.         764.         211.          64.
#  751.33333333 586.          93.         792.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.533333333333334}
# step 77
# 	action [1 0 0]
# 	observation [258.33333333 661.66666667 352.          70.         559.66666667
#   30.          68.         545.66666667  61.         129.
#  920.         128.         120.         807.66666667 207.
#   66.         821.33333333 427.         138.         652.
#  487.         127.         755.66666667 211.          64.
#  743.         586.          93.         784.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.5666666666666673}
# step 78
# 	action [1 0 0]
# 	observation [250.         653.33333333 352.          70.         551.33333333
#   30.          68.         537.33333333  61.         129.
#  920.         128.         120.         799.33333333 207.
#   66.         813.         427.         138.         643.66666667
#  487.         127.         747.33333333 211.          64.
#  734.66666667 586.          93.         776.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.6000000000000005}
# step 79
# 	action [1 0 0]
# 	observation [241.66666667 645.         352.          70.         543.
#   30.          68.         529.          61.         129.
#  920.         128.         120.         791.         207.
#   66.         804.66666667 427.         138.         635.33333333
#  487.         127.         739.         211.          64.
#  726.33333333 586.          93.         767.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.6333333333333337}
# step 80
# 	action [1 0 0]
# 	observation [233.33333333 636.66666667 352.          70.         534.66666667
#   30.          68.         520.66666667  61.         129.
#  920.         128.         120.         782.66666667 207.
#   66.         796.33333333 427.         138.         627.
#  487.         127.         730.66666667 211.          64.
#  718.         586.          93.         759.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.666666666666667}
# step 81
# 	action [1 0 0]
# 	observation [225.         628.33333333 352.          70.         526.33333333
#   30.          68.         512.33333333  61.         129.
#  920.         128.         120.         774.33333333 207.
#   66.         788.         427.         138.         618.66666667
#  487.         127.         722.33333333 211.          64.
#  709.66666667 586.          93.         751.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.7}
# step 82
# 	action [1 0 0]
# 	observation [216.66666667 620.         352.          70.         518.
#   30.          68.         504.          61.         129.
#  920.         128.         120.         766.         207.
#   66.         779.66666667 427.         138.         610.33333333
#  487.         127.         714.         211.          64.
#  701.33333333 586.          93.         742.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.7333333333333334}
# step 83
# 	action [1 0 0]
# 	observation [208.33333333 611.66666667 352.          70.         509.66666667
#   30.          68.         495.66666667  61.         129.
#  920.         128.         120.         757.66666667 207.
#   66.         771.33333333 427.         138.         602.
#  487.         127.         705.66666667 211.          64.
#  693.         586.          93.         734.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.7666666666666666}
# step 84
# 	action [1 0 0]
# 	observation [200.         603.33333333 352.          70.         501.33333333
#   30.          68.         487.33333333  61.         129.
#  920.         128.         120.         749.33333333 207.
#   66.         763.         427.         138.         593.66666667
#  487.         127.         697.33333333 211.          64.
#  684.66666667 586.          93.         726.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.8}
# step 85
# 	action [1 0 1]
# 	observation [191.66666667 595.         352.          70.         493.
#   30.          68.         479.          61.         129.
#  920.         128.         120.         741.         207.
#   66.         754.66666667 427.         138.         585.33333333
#  487.         127.         689.         211.          64.
#  676.33333333 586.          93.         717.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.833333333333333}
# step 86
# 	action [1 0 1]
# 	observation [183.33333333 586.66666667 352.          70.         484.66666667
#   30.          68.         470.66666667  61.         129.
#  920.         128.         120.         732.66666667 207.
#   66.         746.33333333 427.         138.         577.
#  487.         127.         680.66666667 211.          64.
#  668.         586.          93.         709.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.8666666666666663}
# step 87
# 	action [1 0 1]
# 	observation [175.         578.33333333 352.          70.         476.33333333
#   30.          68.         462.33333333  61.         129.
#  911.66666667 128.         120.         724.33333333 207.
#   66.         738.         427.         138.         568.66666667
#  487.         127.         672.33333333 211.          64.
#  659.66666667 586.          93.         701.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.8999999999999995}
# step 88
# 	action [1 0 1]
# 	observation [166.66666667 570.         352.          70.         468.
#   30.          68.         454.          61.         129.
#  903.33333333 128.         120.         716.         207.
#   66.         729.66666667 427.         138.         560.33333333
#  487.         127.         664.         211.          64.
#  651.33333333 586.          93.         692.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.9333333333333327}
# step 89
# 	action [1 0 1]
# 	observation [158.33333333 561.66666667 352.          70.         459.66666667
#   30.          68.         445.66666667  61.         129.
#  895.         128.         120.         707.66666667 207.
#   66.         721.33333333 427.         138.         552.
#  487.         127.         655.66666667 211.          64.
#  643.         586.          93.         684.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.966666666666666}
# step 90
# 	action [0 1 1]
# 	observation [166.66666667 553.33333333 352.          70.         451.33333333
#   30.          68.         437.33333333  61.         129.
#  886.66666667 128.         120.         699.33333333 207.
#   66.         713.         427.         138.         543.66666667
#  487.         127.         647.33333333 211.          64.
#  634.66666667 586.          93.         676.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 2.999999999999999}
# step 91
# 	action [0 1 1]
# 	observation [175.         545.         352.          70.         443.
#   30.          68.         429.          61.         129.
#  878.33333333 128.         120.         691.         207.
#   66.         704.66666667 427.         138.         535.33333333
#  487.         127.         639.         211.          64.
#  626.33333333 586.          93.         667.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.0333333333333323}
# step 92
# 	action [0 1 1]
# 	observation [183.33333333 536.66666667 352.          70.         434.66666667
#   30.          68.         420.66666667  61.         129.
#  870.         128.         120.         682.66666667 207.
#   66.         696.33333333 427.         138.         527.
#  487.         127.         630.66666667 211.          64.
#  618.         586.          93.         659.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.0666666666666655}
# step 93
# 	action [0 1 1]
# 	observation [191.66666667 528.33333333 352.          70.         426.33333333
#   30.          68.         412.33333333  61.         129.
#  861.66666667 128.         120.         674.33333333 207.
#   66.         688.         427.         138.         518.66666667
#  487.         127.         622.33333333 211.          64.
#  609.66666667 586.          93.         651.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.0999999999999988}
# step 94
# 	action [0 1 1]
# 	observation [200.         520.         352.          70.         418.
#   30.          68.         404.          61.         129.
#  853.33333333 128.         120.         666.         207.
#   66.         679.66666667 427.         138.         510.33333333
#  487.         127.         614.         211.          64.
#  601.33333333 586.          93.         642.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.133333333333332}
# step 95
# 	action [0 1 1]
# 	observation [208.33333333 511.66666667 352.          70.         409.66666667
#   30.          68.         395.66666667  61.         129.
#  845.         128.         120.         657.66666667 207.
#   66.         671.33333333 427.         138.         502.
#  487.         127.         605.66666667 211.          64.
#  593.         586.          93.         634.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.166666666666665}
# step 96
# 	action [0 1 1]
# 	observation [216.66666667 503.33333333 352.          70.         401.33333333
#   30.          68.         387.33333333  61.         129.
#  836.66666667 128.         120.         649.33333333 207.
#   66.         663.         427.         138.         493.66666667
#  487.         127.         597.33333333 211.          64.
#  584.66666667 586.          93.         626.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.1999999999999984}
# step 97
# 	action [0 1 1]
# 	observation [225.         495.         352.          70.         393.
#   30.          68.         379.          61.         129.
#  828.33333333 128.         120.         641.         207.
#   66.         654.66666667 427.         138.         485.33333333
#  487.         127.         589.         211.          64.
#  576.33333333 586.          93.         617.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.2333333333333316}
# step 98
# 	action [0 1 1]
# 	observation [233.33333333 486.66666667 352.          70.         384.66666667
#   30.          68.         370.66666667  61.         129.
#  820.         128.         120.         632.66666667 207.
#   66.         646.33333333 427.         138.         477.
#  487.         127.         580.66666667 211.          64.
#  568.         586.          93.         609.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.266666666666665}
# step 99
# 	action [0 1 1]
# 	observation [241.66666667 478.33333333 352.          70.         376.33333333
#   30.          68.         362.33333333  61.         129.
#  811.66666667 128.         120.         624.33333333 207.
#   66.         638.         427.         138.         468.66666667
#  487.         127.         572.33333333 211.          64.
#  559.66666667 586.          93.         601.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.299999999999998}
# step 100
# 	action [0 1 1]
# 	observation [250.         470.         352.          70.         368.
#   30.          68.         354.          61.         129.
#  803.33333333 128.         120.         616.         207.
#   66.         629.66666667 427.         138.         460.33333333
#  487.         127.         564.         211.          64.
#  551.33333333 586.          93.         592.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.3333333333333313}
# step 101
# 	action [0 1 1]
# 	observation [258.33333333 461.66666667 352.          70.         359.66666667
#   30.          68.         345.66666667  61.         129.
#  795.         128.         120.         607.66666667 207.
#   66.         621.33333333 427.         138.         452.
#  487.         127.         555.66666667 211.          64.
#  543.         586.          93.         584.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.3666666666666645}
# step 102
# 	action [0 1 1]
# 	observation [266.66666667 453.33333333 352.          70.         351.33333333
#   30.          68.         337.33333333  61.          96.
#  786.66666667 128.         120.         599.33333333 207.
#   66.         613.         427.         138.         443.66666667
#  487.         127.         547.33333333 211.          64.
#  534.66666667 586.          93.         576.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.3999999999999977}
# step 103
# 	action [0 1 1]
# 	observation [275.         445.         352.          70.         343.
#   30.          68.         329.          61.          96.
#  778.33333333 128.         120.         591.         207.
#   66.         604.66666667 427.         138.         435.33333333
#  487.         127.         539.         211.          64.
#  526.33333333 586.          93.         567.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.433333333333331}
# step 104
# 	action [0 1 1]
# 	observation [283.33333333 436.66666667 352.          70.         334.66666667
#   30.          68.         320.66666667  61.          96.
#  770.         128.         120.         582.66666667 207.
#   66.         596.33333333 427.         138.         427.
#  487.         127.         530.66666667 211.          64.
#  518.         586.          93.         559.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.466666666666664}
# step 105
# 	action [0 1 1]
# 	observation [291.66666667 428.33333333 352.          70.         326.33333333
#   30.          68.         312.33333333  61.          96.
#  761.66666667 128.         120.         574.33333333 207.
#   66.         588.         427.         138.         418.66666667
#  487.         127.         522.33333333 211.          64.
#  509.66666667 586.          93.         551.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.4999999999999973}
# step 106
# 	action [0 1 1]
# 	observation [300.         420.         352.          70.         318.
#   30.          68.         304.          61.          96.
#  753.33333333 128.         120.         566.         207.
#   66.         579.66666667 427.         138.         410.33333333
#  487.         127.         514.         211.          48.
#  501.33333333 586.          93.         542.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.5333333333333306}
# step 107
# 	action [0 1 1]
# 	observation [308.33333333 411.66666667 352.          70.         309.66666667
#   30.          68.         295.66666667  61.          96.
#  745.         128.         120.         557.66666667 207.
#   66.         571.33333333 427.         138.         402.
#  487.         127.         505.66666667 211.          48.
#  493.         586.          93.         534.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.5666666666666638}
# step 108
# 	action [0 1 1]
# 	observation [316.66666667 403.33333333 352.          70.         301.33333333
#   30.          68.         287.33333333  61.          96.
#  736.66666667 128.         120.         549.33333333 207.
#   66.         563.         427.         138.         393.66666667
#  487.         127.         497.33333333 211.          36.
#  484.66666667 586.          93.         526.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.599999999999997}
# step 109
# 	action [0 1 1]
# 	observation [325.         395.         352.          70.         293.
#   30.          68.         279.          61.          96.
#  728.33333333 128.         120.         541.         207.
#   66.         554.66666667 427.         138.         385.33333333
#  487.         127.         489.         211.          27.
#  476.33333333 586.          93.         517.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.63333333333333}
# step 110
# 	action [0 1 1]
# 	observation [333.33333333 386.66666667 352.          70.         284.66666667
#   30.          68.         270.66666667  61.          96.
#  720.         128.         120.         532.66666667 207.
#   49.         546.33333333 427.         138.         377.
#  487.         127.         480.66666667 211.          27.
#  468.         586.          93.         509.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.6666666666666634}
# step 111
# 	action [0 1 1]
# 	observation [341.66666667 378.33333333 352.          70.         276.33333333
#   30.          68.         262.33333333  61.          96.
#  711.66666667 128.         120.         524.33333333 207.
#   49.         538.         427.         138.         368.66666667
#  487.         127.         472.33333333 211.          20.
#  459.66666667 586.          93.         501.         342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.6999999999999966}
# step 112
# 	action [0 1 1]
# 	observation [350.         370.         352.          70.         268.
#   30.          68.         254.          61.          96.
#  703.33333333 128.         120.         516.         207.
#   49.         529.66666667 427.         138.         360.33333333
#  487.         127.         916.66666667 481.         125.
#  451.33333333 586.          93.         492.66666667 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.73333333333333}
# step 113
# 	action [0 1 1]
# 	observation [358.33333333 361.66666667 352.          70.         259.66666667
#   30.          68.         245.66666667  61.          96.
#  695.         128.         120.         507.66666667 207.
#   49.         521.33333333 427.         138.         352.
#  487.         127.         908.33333333 481.         125.
#  443.         586.          93.         484.33333333 342.
#  101.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 3.766666666666663}
# step 114
# 	action [0 1 1]
# 	observation [366.66666667 353.33333333 352.          70.         251.33333333
#   30.          68.         237.33333333  61.          96.
#  686.66666667 128.         120.         499.33333333 207.
#   36.         513.         427.         138.         343.66666667
#  487.         127.         900.         481.         125.
# ...
#   -29.66666667  124.           62.          556.33333333   50.
#    73.          641.66666667   84.           75.         -146.33333333
#    53.          137.          845.66666667  295.           72.
#  -105.           31.           70.          346.33333333  124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 21.566666666666897}
# step 648
# 	action [1 0 1]
# 	observation [ 425.          644.66666667  165.           39.          844.33333333
#   250.           64.           27.66666667  170.           24.
#   -38.          124.           62.          548.           50.
#    73.          633.33333333   84.           75.         -154.66666667
#    53.          137.          837.33333333  295.           72.
#  -113.33333333   31.           70.          338.          124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 21.600000000000232}
# step 649
# 	action [1 0 1]
# 	observation [ 416.66666667  636.33333333  165.           39.          836.
#   250.           36.           19.33333333  170.           24.
#   -46.33333333  124.           62.          539.66666667   50.
#    73.          625.           84.           75.         -163.
#    53.          137.          829.          295.           54.
#  -121.66666667   31.           70.          329.66666667  124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 21.633333333333567}
# step 650
# 	action [1 0 1]
# 	observation [ 408.33333333  628.          165.           39.          827.66666667
#   250.           36.           11.          170.           24.
#   -54.66666667  124.           62.          531.33333333   50.
#    73.          616.66666667   84.           75.         -171.33333333
#    53.          137.          820.66666667  295.           54.
#  -130.           31.           70.          321.33333333  124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 21.666666666666902}
# step 651
# 	action [1 0 1]
# 	observation [ 400.          619.66666667  165.           39.          819.33333333
#   250.           27.            2.66666667  170.           24.
#   -63.          124.           62.          523.           50.
#    73.          608.33333333   84.           75.         -179.66666667
#    53.          137.          812.33333333  295.           40.
#  -138.33333333   31.           70.          313.          124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 21.700000000000237}
# step 652
# 	action [1 0 1]
# 	observation [ 391.66666667  611.33333333  165.           39.          811.
#   250.           27.           -5.66666667  170.           24.
#   -71.33333333  124.           62.          514.66666667   50.
#    73.          600.           84.           75.         -188.
#    53.          137.          804.          295.           30.
#   897.          581.           97.          304.66666667  124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 21.733333333333572}
# step 653
# 	action [1 0 1]
# 	observation [ 383.33333333  603.          165.           39.          802.66666667
#   250.           27.          -14.          170.           24.
#   -79.66666667  124.           62.          506.33333333   50.
#    73.          591.66666667   84.           75.         -196.33333333
#    53.          137.          795.66666667  295.           22.
#   888.66666667  581.           97.          296.33333333  124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 21.766666666666907}
# step 654
# 	action [1 0 1]
# 	observation [ 375.          594.66666667  165.           39.          794.33333333
#   250.           27.          -22.33333333  170.           24.
#   -88.          124.           62.          498.           50.
#    73.          583.33333333   84.           75.         -204.66666667
#    53.          137.          907.66666667    5.          116.
#   880.33333333  581.           97.          288.          124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 21.800000000000242}
# step 655
# 	action [1 0 1]
# 	observation [ 366.66666667  586.33333333  165.           39.          786.
#   250.           27.          -30.66666667  170.           24.
#   -96.33333333  124.           62.          489.66666667   50.
#    73.          575.           84.           75.         -213.
#    53.          137.          899.33333333    5.          116.
#   872.          581.           97.          279.66666667  124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 21.833333333333577}
# step 656
# 	action [1 0 1]
# 	observation [ 358.33333333  578.          165.           39.          777.66666667
#   250.           27.          -39.          170.           24.
#  -104.66666667  124.           62.          481.33333333   50.
#    73.          566.66666667   84.           75.         -221.33333333
#    53.          137.          891.            5.          116.
#   863.66666667  581.           97.          271.33333333  124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 21.866666666666912}
# step 657
# 	action [1 0 1]
# 	observation [ 350.          569.66666667  165.           39.          769.33333333
#   250.           27.          -47.33333333  170.           24.
#  -113.          124.           62.          473.           50.
#    73.          558.33333333   84.           75.         -229.66666667
#    53.          137.          882.66666667    5.          116.
#   855.33333333  581.           97.          263.          124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 21.900000000000247}
# step 658
# 	action [1 0 1]
# 	observation [ 341.66666667  561.33333333  165.           39.          761.
#   250.           27.          850.          594.           50.
#  -121.33333333  124.           62.          464.66666667   50.
#    73.          550.           84.           75.         -238.
#    53.          137.          874.33333333    5.          116.
#   847.          581.           97.          254.66666667  124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 21.933333333333582}
# step 659
# 	action [1 0 1]
# 	observation [ 333.33333333  553.          165.           39.          752.66666667
#   250.           27.          841.66666667  594.           50.
#   922.          231.          122.          456.33333333   50.
#    73.          541.66666667   84.           75.         -246.33333333
#    53.          137.          866.            5.          116.
#   838.66666667  581.           97.          246.33333333  124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 21.966666666666917}
# step 660
# 	action [1 0 1]
# 	observation [ 325.          544.66666667  165.           39.          744.33333333
#   250.           27.          833.33333333  594.           50.
#   913.66666667  231.          122.          448.           50.
#    73.          533.33333333   84.           75.         -254.66666667
#    53.          137.          857.66666667    5.          116.
#   830.33333333  581.           97.          238.          124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.000000000000252}
# step 661
# 	action [1 0 1]
# 	observation [ 316.66666667  536.33333333  165.           39.          736.
#   250.           27.          825.          594.           50.
#   905.33333333  231.          122.          439.66666667   50.
#    73.          525.           84.           75.         -263.
#    53.          137.          849.33333333    5.          116.
#   822.          581.           97.          229.66666667  124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.033333333333587}
# step 662
# 	action [1 0 1]
# 	observation [ 308.33333333  528.          165.           39.          727.66666667
#   250.           27.          816.66666667  594.           50.
#   897.          231.          122.          431.33333333   50.
#    73.          516.66666667   84.           75.         -271.33333333
#    53.          137.          841.            5.          116.
#   813.66666667  581.           97.          221.33333333  124.
#    63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.066666666666922}
# step 663
# 	action [1 0 1]
# 	observation [300.         519.66666667 165.          39.         719.33333333
#  250.          27.         808.33333333 594.          50.
#  888.66666667 231.         122.         423.          50.
#   73.         508.33333333  84.          75.         884.
#  163.          84.         832.66666667   5.         116.
#  805.33333333 581.          97.         213.         124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.100000000000257}
# step 664
# 	action [1 0 1]
# 	observation [291.66666667 511.33333333 165.          39.         711.
#  250.          27.         800.         594.          50.
#  880.33333333 231.         122.         414.66666667  50.
#   73.         500.          84.          75.         875.66666667
#  163.          84.         824.33333333   5.         116.
#  797.         581.          97.         204.66666667 124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.133333333333592}
# step 665
# 	action [1 0 1]
# 	observation [283.33333333 503.         165.          39.         702.66666667
#  250.          27.         791.66666667 594.          50.
#  872.         231.         122.         406.33333333  50.
#   73.         491.66666667  84.          75.         867.33333333
#  163.          84.         816.           5.         116.
#  788.66666667 581.          97.         196.33333333 124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.166666666666927}
# step 666
# 	action [1 0 1]
# 	observation [275.         494.66666667 165.          39.         694.33333333
#  250.          27.         783.33333333 594.          50.
#  863.66666667 231.         122.         398.          50.
#   73.         483.33333333  84.          75.         859.
#  163.          84.         807.66666667   5.         116.
#  780.33333333 581.          97.         188.         124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.200000000000262}
# step 667
# 	action [1 0 1]
# 	observation [266.66666667 486.33333333 165.          39.         686.
#  250.          27.         775.         594.          50.
#  855.33333333 231.         122.         389.66666667  50.
#   73.         475.          84.          75.         850.66666667
#  163.          84.         799.33333333   5.         116.
#  772.         581.          97.         179.66666667 124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.233333333333597}
# step 668
# 	action [1 0 1]
# 	observation [258.33333333 478.         165.          39.         677.66666667
#  250.          27.         766.66666667 594.          50.
#  847.         231.         122.         381.33333333  50.
#   73.         466.66666667  84.          75.         842.33333333
#  163.          84.         791.           5.         116.
#  763.66666667 581.          97.         171.33333333 124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.266666666666932}
# step 669
# 	action [1 0 1]
# 	observation [250.         469.66666667 165.          39.         669.33333333
#  250.          27.         758.33333333 594.          50.
#  838.66666667 231.         122.         373.          50.
#   73.         458.33333333  84.          75.         834.
#  163.          84.         782.66666667   5.         116.
#  755.33333333 581.          97.         163.         124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.300000000000267}
# step 670
# 	action [1 0 1]
# 	observation [241.66666667 461.33333333 165.          39.         661.
#  250.          27.         750.         594.          50.
#  830.33333333 231.         122.         364.66666667  50.
#   73.         450.          84.          75.         825.66666667
#  163.          84.         774.33333333   5.         116.
#  747.         581.          97.         154.66666667 124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.333333333333602}
# step 671
# 	action [1 0 1]
# 	observation [233.33333333 453.         165.          39.         652.66666667
#  250.          27.         741.66666667 594.          50.
#  822.         231.         122.         356.33333333  50.
#   73.         441.66666667  84.          75.         817.33333333
#  163.          84.         766.           5.         116.
#  738.66666667 581.          97.         146.33333333 124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.366666666666937}
# step 672
# 	action [1 0 1]
# 	observation [225.         444.66666667 165.          39.         644.33333333
#  250.          27.         733.33333333 594.          50.
#  813.66666667 231.         122.         348.          50.
#   73.         433.33333333  84.          75.         809.
#  163.          84.         757.66666667   5.         116.
#  730.33333333 581.          72.         138.         124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.400000000000272}
# step 673
# 	action [1 0 1]
# 	observation [216.66666667 436.33333333 165.          39.         636.
#  250.          27.         725.         594.          50.
#  805.33333333 231.         122.         339.66666667  50.
#   73.         425.          84.          75.         800.66666667
#  163.          84.         749.33333333   5.         116.
#  722.         581.          72.         129.66666667 124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.433333333333607}
# step 674
# 	action [1 0 1]
# 	observation [208.33333333 428.         165.          39.         627.66666667
#  250.          27.         716.66666667 594.          50.
#  797.         231.         122.         331.33333333  50.
#   73.         416.66666667  84.          75.         792.33333333
#  163.          84.         741.           5.         116.
#  713.66666667 581.          72.         121.33333333 124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.466666666666942}
# step 675
# 	action [1 0 1]
# 	observation [200.         419.66666667 165.          39.         619.33333333
#  250.          27.         708.33333333 594.          50.
#  788.66666667 231.         122.         323.          50.
#   73.         408.33333333  84.          75.         784.
#  163.          84.         732.66666667   5.         116.
#  705.33333333 581.          54.         113.         124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.500000000000277}
# step 676
# 	action [1 0 1]
# 	observation [191.66666667 411.33333333 165.          39.         611.
#  250.          27.         700.         594.          50.
#  780.33333333 231.         122.         314.66666667  50.
#   73.         400.          84.          75.         775.66666667
#  163.          84.         724.33333333   5.         116.
#  697.         581.          54.         104.66666667 124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.533333333333612}
# step 677
# 	action [1 0 1]
# 	observation [183.33333333 403.         165.          39.         602.66666667
#  250.          27.         691.66666667 594.          50.
#  772.         231.         122.         306.33333333  50.
#   73.         391.66666667  84.          75.         767.33333333
#  163.          84.         716.           5.         116.
#  688.66666667 581.          54.          96.33333333 124.
#   63.        ]
# 	reward 1
# 	terminated False
# 	truncated False
# 	info {'t': 22.566666666666947}
# step 678
# 	action [1 1 1]
# 	observation [175.         394.66666667 165.          39.         594.33333333
#  250.          27.         683.33333333 594.          50.
#  763.66666667 231.         122.         298.          50.
#   73.         383.33333333  84.          75.         759.
#  163.          84.         707.66666667   5.         116.
#  680.33333333 581.          54.          88.         124.
#   63.        ]
# 	reward 1
# 	terminated True
# 	truncated False
# 	info {'t': 22.600000000000282}
# Total reward 678
